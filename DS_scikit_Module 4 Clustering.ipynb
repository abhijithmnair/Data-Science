# %% [markdown]
# # Module 4 Clustering

# %% [markdown]
# ## Load the Data

# %%
# %matplotlib inline

# %%
from sklearn.datasets.samples_generator import make_blobs

centers = [[1,1],[1.5,1.5],[2,2]]
X,y = make_blobs(n_samples=100,centers = centers,cluster_std=0.1)

import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1])

# %% [markdown]
# ## load the Model

# %%
from sklearn.cluster import KMeans

cluster = KMeans(n_clusters=3,random_state=10)

# %% [markdown]
# ## Train thhe Model

# %%
cluster.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=10, tol=0.0001, verbose=0)

# %% [markdown]
# ## Evaluate the Model

# %%
cluster.labels_
# Out:
# array([2, 0, 1, 0, 0, 2, 1, 1, 1, 0, 0, 1, 2, 1, 2, 0, 2, 1, 1, 1, 0, 0,
#        1, 1, 1, 1, 0, 1, 0, 2, 1, 0, 1, 2, 1, 2, 1, 2, 2, 2, 2, 1, 1, 0,
#        1, 2, 2, 2, 1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 2, 0, 2, 1, 0, 1, 1,
#        2, 2, 0, 0, 1, 0, 1, 0, 0, 0, 1, 1, 1, 2, 0, 1, 0, 2, 2, 2, 2, 2,
#        1, 0, 1, 2, 0, 2, 0, 2, 2, 2, 2, 0])

# %%
cluster.cluster_centers_
# Out:
# array([[0.99641743, 0.99456523],
#        [2.01378723, 1.99525174],
#        [1.49746658, 1.50356681]])

# %%
plt.subplot(1,2,1)
plt.scatter(X[:,0],X[:,1],c=y)
plt.title("Actual")
plt.subplot(1,2,2)
plt.scatter(X[:,0],X[:,1],c=cluster.labels_)
plt.title("Prediction")
# Out:
# Text(0.5, 1.0, 'Prediction')

# %% [markdown]
# ## Ex: KMeans Clustering

# %%
from sklearn import datasets

iris = datasets.load_iris()
X,y = iris.data,iris.target

from sklearn.cluster import KMeans

cluster = KMeans(n_clusters=3,random_state=10)
cluster.fit(X)

a = 1
b = 2
plt.subplot(1,2,1)
plt.scatter(X[:,a],X[:,b],c=y)
plt.xlabel(iris.feature_names[a])
plt.ylabel(iris.feature_names[b])
plt.title("Actual")
plt.subplot(1,2,2)
plt.scatter(X[:,a],X[:,b],c=cluster.labels_)
plt.title("Prediction")
# Out:
# Text(0.5, 1.0, 'Prediction')

# %% [markdown]
# ## MeanShift Clustering

# %%
from sklearn import datasets

iris = datasets.load_iris()
X,y = iris.data,iris.target

# from sklearn.datasets.samples_generator import make_blobs

# centers = [[1,1],[1.5,1.5],[1.1,1.2]]
# X,y = make_blobs(n_samples=100,centers = centers,cluster_std=0.1)

import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1])

from sklearn.cluster import MeanShift

cluster = MeanShift()
cluster.fit(X)

a = 0
b = 1
plt.subplot(1,2,1)
plt.scatter(X[:,a],X[:,b],c=y)
plt.xlabel(iris.feature_names[a])
plt.ylabel(iris.feature_names[b])
plt.title("Actual")
plt.subplot(1,2,2)
plt.scatter(X[:,a],X[:,b],c=cluster.labels_)
plt.title("Prediction")
# Out:
# Text(0.5, 1.0, 'Prediction')

# %% [markdown]
# ## Agglormerative Clustering

# %%
from sklearn import datasets

iris = datasets.load_iris()
X,y = iris.data,iris.target

import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1])

from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters = 3)
cluster.fit(X)

a = 1
b = 2
plt.subplot(1,2,1)
plt.scatter(X[:,a],X[:,b],c=y)
plt.xlabel(iris.feature_names[a])
plt.ylabel(iris.feature_names[b])
plt.title("Actual")
plt.subplot(1,2,2)
plt.scatter(X[:,a],X[:,b],c=cluster.labels_)
plt.title("Prediction")
# Out:
# Text(0.5, 1.0, 'Prediction')
