# %% [markdown]
# #ETL Extract Transform Load
# Data can be in text,html,pdf, zip
#
# --> extract 1 - get in text
# --> extract 2 - extract the data

# %%
import re

# %%
# when you are working in Regular expressions datatype should be str or byte
re.match('a','apple')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
re.match('ap','apple')
# Out:
# <re.Match object; span=(0, 2), match='ap'>

# %%
re.match('apt','apple')

# %%
re.search('ppl','apple')
# Out:
# <re.Match object; span=(1, 4), match='ppl'>

# %%
re.search('ap.','apple')
# Out:
# <re.Match object; span=(0, 3), match='app'>

# %%
re.search('a.p','apple')
# Out:
# <re.Match object; span=(0, 3), match='app'>

# %%
re.search('ap.*','apple')
# Out:
# <re.Match object; span=(0, 5), match='apple'>

# %%
re.search('ap*.','apple')
# Out:
# <re.Match object; span=(0, 4), match='appl'>

# %%
re.search('ap*','apple')
# Out:
# <re.Match object; span=(0, 3), match='app'>

# %%
re.search('a?','apple')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
re.search('a{3}','aaaapple')
# Out:
# <re.Match object; span=(0, 3), match='aaa'>

# %%
re.search('a{3,6}','aaaaapple')
# Out:
# <re.Match object; span=(0, 5), match='aaaaa'>

# %%
re.search('\$.','100$s')
# Out:
# <re.Match object; span=(3, 5), match='$s'>

# %%
re.search('[abc]','apple')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
re.search('a|b','banana')
# Out:
# <re.Match object; span=(0, 1), match='b'>

# %%
re.search("https?\://(.+)","https://google.com")
# Out:
# <re.Match object; span=(0, 18), match='https://google.com'>

# %%
m= re.search

# %%
t=open('sci_data_new.txt','r')

# %%
l
# Out:
# <_io.TextIOWrapper name='sci_data_new.txt' mode='r' encoding='cp1252'>

# %%
lines= t.readlines()

# %%
p = ''
for l in lines:
    s = p+l
    m = re.search("^\d{1,3}",s)
    if m is not None:
        m2 = re.search('d{4}',s)
        if m2 is not None:
            s = s[:m2.end()]
        p= ''
        
        n= re.search('\d{4} $',s)
        if n is not None:
            print(">>"+s)
        else:
            p=s
# Out:
# >>1 C.A. No. 9818/2011
#
# >>2 C.A. No. 315/2013
#
# >>3 Crl.A. No. 1738/2015
#
# >>4 C.A. No. 10126/2018
#
# >>5 C.A. No. 7107/2017
#
# >>6 SLP(C) No. 32748/2018
#
# >>7 W.P.(C) No. 297/2019
#
# >>8 Diary No. 22627-2018
#
# >>9 CONMT.PET.(C) No.
# 2240/2018 in C.A. No.
# 3194/2016
#
# >>10 Diary No. 35193-2018
#
# >>11 Diary No. 35594-2018
#
# >>12 Diary No. 41582-2018
#
# >>13 SLP(C) No. 2899/2019
#
# >>14 Diary No. 1191-2019
#
# >>15 CONMT.PET.(C) No.
# 149/2019 in C.A. No.
# 10081/2014
#
# >>16 Diary No. 3027-2019
#
# >>17 Diary No. 4112-2019
#
# >>18 Diary No. 4116-2019
#
# >>19 W.P.(C) No. 269/2019
#
# >>20 SLP(C) No. 5664/2019
#
# >>21 SLP(C) No. 6234/2019
#
# >>22 Diary No. 6182-2019
#
# >>23 Diary No. 6602-2019
#
# >>24 SLP(C) No. 6002/2019
#
# >>25 SLP(C) No. 5994/2019
#
# >>26 W.P.(C) No. 244/2019
#
# >>27 W.P.(C) No. 255/2019
#
# >>27.1 Connected
# W.P.(C) No. 262/2019
#
# >>28 SLP(C) No. 6270/2019
#
# >>29 SLP(C) No. 6368/2019
#
# >>30 Diary No. 21557-2018
#
# ...

# %%
p = ''
for l in lines:
    s = p+l
    m = re.search("^\d{1,3}",s)
    if m is not None:
        m2 = re.search('d{4}',s)
        if m2 is not None:
            s = s[:m2.end()]
        p= ''
        
        n= re.search('\d{4} $',s)
        if n is not None:
            print(">>"+s)
        else:
            p=s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9cc161acf043> in <module>
#       1 p = ''
# ----> 2 for l in lines:
#       3     s = p+l
#       4     m = re.search("^\d{1,3}",s)
#       5     if m is not None:
#
# NameError: name 'lines' is not defined
