# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib as mp

# %%
# %matplotlib inline

# %%
df= pd.read_csv("zomato.csv")

# %%
df
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           6317637                          Le Petit Souffle           162
# 1           6304287                          Izakaya Kikufuji           162
# 2           6300002                    Heat - Edsa Shangri-La           162
# 3           6318506                                      Ooma           162
# 4           6314302                               Sambo Kojin           162
# 5          18189371                              Din Tai Fung           162
# 6           6300781                                Buffet 101           162
# 7           6301290                                   Vikings           162
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9           6314987                                  Locavore           162
# 10          6309903                          Silantro Fil-Mex           162
# ...

# %%
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Cuisines'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                       French, Japanese, Desserts
# 1                                         Japanese
# 2                 Seafood, Asian, Filipino, Indian
# 3                                  Japanese, Sushi
# 4                                 Japanese, Korean
# 5                                          Chinese
# 6                                  Asian, European
# 7               Seafood, Filipino, Asian, European
# 8                          European, Asian, Indian
# 9                                         Filipino
# 10                               Filipino, Mexican
# 11                   American, Ice Cream, Desserts
# 12                               Filipino, Mexican
# 13                                        Filipino
# 14                                          Korean
# 15               Cafe, American, Italian, Filipino
# 16                                  Italian, Pizza
# 17                                        Filipino
# ...

# %%
df['Country Code'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       162
# 1       162
# 2       162
# 3       162
# 4       162
# 5       162
# 6       162
# 7       162
# 8       162
# 9       162
# 10      162
# 11      162
# 12      162
# 13      162
# 14      162
# 15      162
# 16      162
# 17      162
# 18      162
# 19      162
# 20      162
# 21      162
# 22       30
# 23       30
# 24       30
# 25       30
# 26       30
# 27       30
# 28       30
# 29       30
#        ...
# 9521    208
# 9522    208
# 9523    208
# 9524    208
# 9525    208
# 9526    208
# 9527    208
# 9528    208
# 9529    208
# 9530    208
# 9531    208
# 9532    208
# 9533    208
# 9534    208
# 9535    208
# 9536    208
# 9537    208
# 9538    208
# 9539    208
# 9540    208
# 9541    208
# 9542    208
# 9543    208
# 9544    208
# 9545    208
# 9546    208
# 9547    208
# 9548    208
# 9549    208
# 9550    208
# Name: Country Code, Length: 9551, dtype: int64>

# %%
table = df.pivot_table(values='Cuisines', index='Restaurant Name' ,columns='City', aggfunc=np.median)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-19-637465e839de> in <module>
# ----> 1 table = df.pivot_table(values='Cuisines', index='Restaurant Name' ,columns='City', aggfunc=np.median)
#
# ~\AppData\Local\Continuum\anaconda3a\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5301                            aggfunc=aggfunc, fill_value=fill_value,
#    5302                            margins=margins, dropna=dropna,
# -> 5303                            margins_name=margins_name)
#    5304
#    5305     def stack(self, level=-1, dropna=True):
#
# ~\AppData\Local\Continuum\anaconda3a\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      85     # if we have a categorical
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
# Restaurant ID           9551 non-null int64
# Restaurant Name         9551 non-null object
# Country Code            9551 non-null int64
# City                    9551 non-null object
# Address                 9551 non-null object
# Locality                9551 non-null object
# Locality Verbose        9551 non-null object
# Longitude               9551 non-null float64
# Latitude                9551 non-null float64
# Cuisines                9542 non-null object
# Average Cost for two    9551 non-null int64
# Currency                9551 non-null object
# Has Table booking       9551 non-null object
# Has Online delivery     9551 non-null object
# Is delivering now       9551 non-null object
# Switch to order menu    9551 non-null object
# Price range             9551 non-null int64
# Aggregate rating        9551 non-null float64
# ...

# %%
pd.setoption

# %%
df['Country Code'].describe()
# Out:
# count    9551.000000
# mean       18.365616
# std        56.750546
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max       216.000000
# Name: Country Code, dtype: float64

# %%
df['Cuisines'].describe()
# Out:
# count             9542
# unique            1825
# top       North Indian
# freq               936
# Name: Cuisines, dtype: object

# %%
df1 = df[df['Country Code']==1] 
df1
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 624         3400025                                Jahanpanah             1
# 625         3400341                       Rangrezz Restaurant             1
# 626         3400005                   Time2Eat - Mama Chicken             1
# 627         3400021     Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                            Pinch Of Spice             1
# 629         3400325                                 MoMo Cafe             1
# 630         3400059                     Peshawri - ITC Mughal             1
# 631         3400060                     Taj Bano - ITC Mughal             1
# 632         3400348                                    G Thal             1
# 633         3400072              Dawat-e-Nawab - Radisson Blu             1
# 634         3400073               The Latitude - Radisson Blu             1
# ...

# %%
df[(df['Country Code']==1) & (df['City']=='Agra') & ()]
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
# 629        3400325                              MoMo Cafe             1  Agra
# 630        3400059                  Peshawri - ITC Mughal             1  Agra
# 631        3400060                  Taj Bano - ITC Mughal             1  Agra
# 632        3400348                                 G Thal             1  Agra
# 633        3400072           Dawat-e-Nawab - Radisson Blu             1  Agra
# 634        3400073            The Latitude - Radisson Blu             1  Agra
# ...

# %%
 grouped = df.groupby('Rating color')

# %%
grouped

# %%
df.all()
# Out:
# Restaurant ID            True
# Restaurant Name          True
# Country Code             True
# City                     True
# Address                  True
# Locality                 True
# Locality Verbose         True
# Longitude               False
# Latitude                False
# Cuisines                 True
# Average Cost for two    False
# Currency                 True
# Has Table booking        True
# Has Online delivery      True
# Is delivering now        True
# Switch to order menu     True
# Price range              True
# Aggregate rating        False
# Rating color             True
# Rating text              True
# Votes                   False
# dtype: bool

# %%
df1.columns = ['Restaurant_Unique_id']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-09c120140c81> in <module>
# ----> 1 df1.columns = ['Restaurant_Unique_id']
#
# ~\AppData\Local\Continuum\anaconda3a\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\AppData\Local\Continuum\anaconda3a\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ...

# %%
df.rename(columns={'Rating color': 'Ratingcolor'}, inplace=True)

# %%
df
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 0           6317637                          Le Petit Souffle           162
# 1           6304287                          Izakaya Kikufuji           162
# 2           6300002                    Heat - Edsa Shangri-La           162
# 3           6318506                                      Ooma           162
# 4           6314302                               Sambo Kojin           162
# 5          18189371                              Din Tai Fung           162
# 6           6300781                                Buffet 101           162
# 7           6301290                                   Vikings           162
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9           6314987                                  Locavore           162
# 10          6309903                          Silantro Fil-Mex           162
# ...

# %%
df[(df['Country Code']==1) & (df['Ratingcolor']=='Dark Green') & (df['Aggregate rating']>=4.5) ]
# Out:
#       Restaurant ID                       Restaurant Name  Country Code  \
# 637         3400346                       Sheroes Hangout             1
# 646        18396250                         Huber & Holly             1
# 653        18385201                              Cryo Lab             1
# 660          113325                        Nini's Kitchen             1
# 727           58268      The Fatty Bao - Asian Gastro Bar             1
# 728           51705                                  Toit             1
# 733        18359919                                Onesta             1
# 734        18439634                    ECHOES Koramangala             1
# 735           51040                              Truffles             1
# 738        18385443                    Koramangala Social             1
# 739           56618             AB's - Absolute Barbecues             1
# 741        18366652                                Onesta             1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import datetime

# %%
dti = pd.to_datetime(['1/1/2018', np.datetime64('2018-01-01'),
   ...:                       datetime.datetime(2018, 1, 1)])

# %%
dti
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)

# %%
 dti = pd.date_range('2018-01-01', periods=3, freq='H')
dti
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
dti = dti.tz_localize('UTC')

# %%
dti
# Out:
# DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='H')

# %%
dti =dti.tz_convert('Asia/Kolkata')
dti
# Out:
# DatetimeIndex(['2018-01-01 05:30:00+05:30', '2018-01-01 06:30:00+05:30',
#                '2018-01-01 07:30:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', freq='H')

# %%
idx = pd.date_range('2018-01-01', periods=5, freq='H')

# %%
idx
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
ts = pd.Series(range(len(idx)), index=idx)

# %%
ts
# Out:
# 2018-01-01 00:00:00    0
# 2018-01-01 01:00:00    1
# 2018-01-01 02:00:00    2
# 2018-01-01 03:00:00    3
# 2018-01-01 04:00:00    4
# Freq: H, dtype: int64

# %%
ts.resample('2H').min()
# Out:
# 2018-01-01 00:00:00    0
# 2018-01-01 02:00:00    2
# 2018-01-01 04:00:00    4
# Freq: 2H, dtype: int64

# %%
x = pd.Timestamp('2019-03-06 15:35:29:05')

# %%
x.day_name()
# Out:
# 'Wednesday'

# %%
y = x + pd.Timedelta('15 days 6 hours 23 minutes 56 seconds')

# %%
y
# Out:
# Timestamp('2019-03-21 06:23:56')

# %%
y.day_name()
# Out:
# 'Thursday'

# %%
pd.Series(pd.period_range('1/1/2011', freq='D', periods=3))
# Out:
# 0   2011-01-01
# 1   2011-01-02
# 2   2011-01-03
# dtype: object

# %%
pd.Series(pd.date_range('1/1/2011', freq='D', periods=3))
# Out:
# 0   2011-01-01
# 1   2011-01-02
# 2   2011-01-03
# dtype: datetime64[ns]

# %%
 pd.Series([pd.DateOffset(5), pd.DateOffset(10)])
# Out:
# 0     <5 * DateOffsets>
# 1    <10 * DateOffsets>
# dtype: object

# %%
pd.Series(pd.date_range('1/1/2011', freq='M', periods=3))
# Out:
# 0   2011-01-31
# 1   2011-02-28
# 2   2011-03-31
# dtype: datetime64[ns]

# %%
pd.Timestamp(pd.NaT)
# Out:
# NaT

# %%
pd.Timestamp(datetime.datetime(2012, 5, 1))
# Out:
# Timestamp('2012-05-01 00:00:00')

# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# %%
df.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_ef1cc310_4007_11e9_bf58_e0d55e6179c0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ef1cc310_4007_11e9_bf58_e0d55e6179c0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_ef1cc310_4007_11e9_bf58_e0d55e6179c0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_ef1cc310_4007_11e9_bf58_e0d55e6179c0row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_ef1cc310_4007_11e9_bf58_e0d55e6179c0row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_ef1cc310_4007_11e9_bf58_e0d55e6179c0row0_col3" class="data row0 col3" >-0.31628</td>
# ...

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
s = df.style.applymap(color_negative_red)
s
# Out:
# <style  type="text/css" >
#     #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row0_col0 {
#             color:  black;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row0_col1 {
#             color:  black;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row0_col2 {
#             color:  black;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row0_col3 {
#             color:  red;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row0_col4 {
#             color:  red;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row1_col0 {
#             color:  black;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row1_col1 {
#             color:  red;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row1_col2 {
#             color:  red;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row1_col3 {
#             color:  black;
#         }    #T_b3446f66_4008_11e9_bfea_e0d55e6179c0row1_col4 {
#             color:  black;
# ...

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
df.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_b5f63434_4009_11e9_bdda_e0d55e6179c0row2_col4 {
#             background-color:  yellow;
#         }    #T_b5f63434_4009_11e9_bdda_e0d55e6179c0row6_col2 {
#             background-color:  yellow;
#         }    #T_b5f63434_4009_11e9_bdda_e0d55e6179c0row8_col1 {
#             background-color:  yellow;
#         }    #T_b5f63434_4009_11e9_bdda_e0d55e6179c0row8_col3 {
#             background-color:  yellow;
#         }    #T_b5f63434_4009_11e9_bdda_e0d55e6179c0row9_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_b5f63434_4009_11e9_bdda_e0d55e6179c0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
# ...

# %%
df.style.\
    applymap(color_negative_red).\
    apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row0_col0 {
#             color:  black;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row0_col1 {
#             color:  black;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row0_col2 {
#             color:  black;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row0_col3 {
#             color:  red;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row0_col4 {
#             color:  red;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row1_col0 {
#             color:  black;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row1_col1 {
#             color:  red;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row1_col2 {
#             color:  red;
#             : ;
#         }    #T_fd361dde_4009_11e9_ab66_e0d55e6179c0row1_col3 {
# ...

# %%
df== df.max()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False   True
# 3  False  False  False  False  False
# 4  False  False  False  False  False
# 5  False  False  False  False  False
# 6  False  False   True  False  False
# 7  False  False  False  False  False
# 8  False   True  False   True  False
# 9   True  False  False  False  False

# %%
df.style.\
    applymap(color_negative_red).\
    apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row0_col0 {
#             color:  black;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row0_col1 {
#             color:  black;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row0_col2 {
#             color:  black;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row0_col3 {
#             color:  red;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row0_col4 {
#             color:  red;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row1_col0 {
#             color:  black;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row1_col1 {
#             color:  red;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row1_col2 {
#             color:  red;
#             : ;
#         }    #T_4b527bae_400b_11e9_ab5b_e0d55e6179c0row1_col3 {
# ...

# %%
df.style.format("{:.2%}")
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_60c563d4_400c_11e9_b040_e0d55e6179c0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_60c563d4_400c_11e9_b040_e0d55e6179c0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_60c563d4_400c_11e9_b040_e0d55e6179c0row0_col0" class="data row0 col0" >100.00%</td>
#         <td id="T_60c563d4_400c_11e9_b040_e0d55e6179c0row0_col1" class="data row0 col1" >132.92%</td>
#         <td id="T_60c563d4_400c_11e9_b040_e0d55e6179c0row0_col2" class="data row0 col2" >nan%</td>
#         <td id="T_60c563d4_400c_11e9_b040_e0d55e6179c0row0_col3" class="data row0 col3" >-31.63%</td>
# ...

# %%
df.style.format({'B': "{:0<4.0f}", 'D': '{:+.2f}'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_9e41a330_400c_11e9_9f19_e0d55e6179c0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9e41a330_400c_11e9_9f19_e0d55e6179c0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_9e41a330_400c_11e9_9f19_e0d55e6179c0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_9e41a330_400c_11e9_9f19_e0d55e6179c0row0_col1" class="data row0 col1" >1000</td>
#         <td id="T_9e41a330_400c_11e9_9f19_e0d55e6179c0row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_9e41a330_400c_11e9_9f19_e0d55e6179c0row0_col3" class="data row0 col3" >-0.32</td>
# ...

# %%
df.style.format({"B": lambda x: "±{:.2f}".format(abs(x))})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_087bad80_400d_11e9_b46c_e0d55e6179c0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_087bad80_400d_11e9_b46c_e0d55e6179c0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_087bad80_400d_11e9_b46c_e0d55e6179c0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_087bad80_400d_11e9_b46c_e0d55e6179c0row0_col1" class="data row0 col1" >±1.33</td>
#         <td id="T_087bad80_400d_11e9_b46c_e0d55e6179c0row0_col2" class="data row0 col2" >nan</td>
#         <td id="T_087bad80_400d_11e9_b46c_e0d55e6179c0row0_col3" class="data row0 col3" >-0.31628</td>
# ...

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = df.style.background_gradient(cmap=cm)
s
# Out:
# C:\Users\HKC05\AppData\Local\Continuum\anaconda3a\lib\site-packages\matplotlib\colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_4adba128_400d_11e9_857a_e0d55e6179c0row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4adba128_400d_11e9_857a_e0d55e6179c0row0_col1 {
#             background-color:  #188d18;
#         }    #T_4adba128_400d_11e9_857a_e0d55e6179c0row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4adba128_400d_11e9_857a_e0d55e6179c0row0_col3 {
#             background-color:  #c7eec7;
#         }    #T_4adba128_400d_11e9_857a_e0d55e6179c0row0_col4 {
#             background-color:  #a6dca6;
#         }    #T_4adba128_400d_11e9_857a_e0d55e6179c0row1_col0 {
#             background-color:  #ccf1cc;
#         }    #T_4adba128_400d_11e9_857a_e0d55e6179c0row1_col1 {
#             background-color:  #c0eac0;
# ...

# %%
print("Cook Book")
# Out:
# Cook Book

# %%
df_mask = pd.DataFrame({'AAA': [True] * 4,
   ...:                         'BBB': [False] * 4,
   ...:                         'CCC': [True, False] * 2})
   ...:

# %%
 df.where(df_mask, -1000)
# Out:
#         A       B       C       D       E
# 0 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 1 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 2 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 3 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 4 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 5 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 6 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 7 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 8 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0
# 9 -1000.0 -1000.0 -1000.0 -1000.0 -1000.0

# %%
 df = pd.DataFrame({'AAA': [4, 5, 6, 7],
   ....:                    'BBB': [10, 20, 30, 40],
   ....:                    'CCC': [100, 50, -30, -50]})
   ....: 
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
aValue = 43.0

# %%
df.loc[(df.CCC - aValue).abs().argsort()]
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 0    4   10  100
# 2    6   30  -30
# 3    7   40  -50

# %%
data = {'AAA': [4, 5, 6, 7],
   ....:         'BBB': [10, 20, 30, 40],
   ....:         'CCC': [100, 50, -30, -50]}
   ....:

# %%
df2 = pd.DataFrame(data=data, index=[1, 2, 3, 4])

# %%
df2.iloc[1:3]
# Out:
#    AAA  BBB  CCC
# 2    5   20   50
# 3    6   30  -30

# %%
df2.loc[1:3]
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30

# %%
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df[~((df.AAA <= 6) & (df.index.isin([0, 2, 4])))]
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 3    7   40  -50
