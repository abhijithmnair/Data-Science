# %% [markdown]
# You will get datasets from...
# https://archive.ics.uci.edu/ml/index.php
#
#
# ******level 1******
#
# iris data --> predict the class of flower based on available attributes
# https://archive.ics.uci.edu/ml/datasets/iris
#
# loan prediction data --> predict if a loan would get approved or not. Classification problem
#
# bigmart sales data --> predict the sales of the store. Regression Problem
#
# boston housing data -->  predict the median value of owner occupied house. Regression problem.
#
# time series analysis data --> predict traffic. Time Series is special case of analysing data
#
# wine quality data --> predict the quality of the wine. classification and regression problem.
# https://archive.ics.uci.edu/ml/datasets/wine+quality
#
# turkiye student evaluation data --> Use classification and clustering to deal with data.
# Unsupervised learning problem.
#
# heights and weights data -->
#
#
# *****level 2 ********
#
# black friday data --> predict purchase amount. Regression problem
#
# human activity --> predict the activity category of a human. Multi classification problem
#
# Text mining dataset --> siam competition 2007 data . Multi classification and high dimensional problem. classify documents according to their labels.
#
# Trip history data--> predict the class of the user . Classification problem
#
# Million song data --> predict the release year of the song. Regression
#
# Census income data --> Predict the income class of US popoulation. Imbalanced classification and machine learning.
#
# Movie lens data --> Recommend new movies to users
#
# twitter classification data --> identify which tweets are 'hate tweets' and which are not. Sentiment analysis problem
#
#
# ******level 3********
#
# identify your digits  --> Identify digits from an image.
#
# urban sound classification --> classify type of sound from audio.
#
# vox celebrity data --> figure out which celebrity the voice belongs to.
#
# imagenet data --> object detection , localization , classification and screen parsing.
#
# chicago crime data --> predict the type of crime . Multi classification problem.
#
# age detection of indian actors data --> predict the age of the actors. scale , pose , expression , illumination , age, resolution , occlusion and makeup
#
# Recommendation engine data --> predict the time taken to solve a problem give the current status of the user.
#
# visualqa data --> use deep learning to answer open - ended questions about images.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('iris.data')

# %%
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# 7    4.4  2.9  1.4  0.2     Iris-setosa
# 8    4.9  3.1  1.5  0.1     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 10   4.8  3.4  1.6  0.2     Iris-setosa
# 11   4.8  3.0  1.4  0.1     Iris-setosa
# 12   4.3  3.0  1.1  0.1     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# 18   5.1  3.8  1.5  0.3     Iris-setosa
# 19   5.4  3.4  1.7  0.2     Iris-setosa
# 20   5.1  3.7  1.5  0.4     Iris-setosa
# 21   4.6  3.6  1.0  0.2     Iris-setosa
# 22   5.1  3.3  1.7  0.5     Iris-setosa
# 23   4.8  3.4  1.9  0.2     Iris-setosa
# 24   5.0  3.0  1.6  0.2     Iris-setosa
# 25   5.0  3.4  1.6  0.4     Iris-setosa
# 26   5.2  3.5  1.5  0.2     Iris-setosa
# 27   5.2  3.4  1.4  0.2     Iris-setosa
# 28   4.7  3.2  1.6  0.2     Iris-setosa
# 29   4.8  3.1  1.6  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 119  6.9  3.2  5.7  2.3  Iris-virginica
# 120  5.6  2.8  4.9  2.0  Iris-virginica
# 121  7.7  2.8  6.7  2.0  Iris-virginica
# 122  6.3  2.7  4.9  1.8  Iris-virginica
# 123  6.7  3.3  5.7  2.1  Iris-virginica
# 124  7.2  3.2  6.0  1.8  Iris-virginica
# 125  6.2  2.8  4.8  1.8  Iris-virginica
# 126  6.1  3.0  4.9  1.8  Iris-virginica
# 127  6.4  2.8  5.6  2.1  Iris-virginica
# 128  7.2  3.0  5.8  1.6  Iris-virginica
# 129  7.4  2.8  6.1  1.9  Iris-virginica
# 130  7.9  3.8  6.4  2.0  Iris-virginica
# 131  6.4  2.8  5.6  2.2  Iris-virginica
# 132  6.3  2.8  5.1  1.5  Iris-virginica
# 133  6.1  2.6  5.6  1.4  Iris-virginica
# 134  7.7  3.0  6.1  2.3  Iris-virginica
# 135  6.3  3.4  5.6  2.4  Iris-virginica
# 136  6.4  3.1  5.5  1.8  Iris-virginica
# 137  6.0  3.0  4.8  1.8  Iris-virginica
# 138  6.9  3.1  5.4  2.1  Iris-virginica
# 139  6.7  3.1  5.6  2.4  Iris-virginica
# 140  6.9  3.1  5.1  2.3  Iris-virginica
# 141  5.8  2.7  5.1  1.9  Iris-virginica
# 142  6.8  3.2  5.9  2.3  Iris-virginica
# 143  6.7  3.3  5.7  2.5  Iris-virginica
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
X = df.iloc[:,1:4]
Y = df.iloc[:,4]

# %%
X
# Out:
#      3.5  1.4  0.2
# 0    3.0  1.4  0.2
# 1    3.2  1.3  0.2
# 2    3.1  1.5  0.2
# 3    3.6  1.4  0.2
# 4    3.9  1.7  0.4
# 5    3.4  1.4  0.3
# 6    3.4  1.5  0.2
# 7    2.9  1.4  0.2
# 8    3.1  1.5  0.1
# 9    3.7  1.5  0.2
# 10   3.4  1.6  0.2
# 11   3.0  1.4  0.1
# 12   3.0  1.1  0.1
# 13   4.0  1.2  0.2
# 14   4.4  1.5  0.4
# 15   3.9  1.3  0.4
# 16   3.5  1.4  0.3
# 17   3.8  1.7  0.3
# 18   3.8  1.5  0.3
# 19   3.4  1.7  0.2
# 20   3.7  1.5  0.4
# 21   3.6  1.0  0.2
# 22   3.3  1.7  0.5
# 23   3.4  1.9  0.2
# 24   3.0  1.6  0.2
# 25   3.4  1.6  0.4
# 26   3.5  1.5  0.2
# 27   3.4  1.4  0.2
# 28   3.2  1.6  0.2
# 29   3.1  1.6  0.2
# ..   ...  ...  ...
# 119  3.2  5.7  2.3
# 120  2.8  4.9  2.0
# 121  2.8  6.7  2.0
# 122  2.7  4.9  1.8
# 123  3.3  5.7  2.1
# 124  3.2  6.0  1.8
# 125  2.8  4.8  1.8
# 126  3.0  4.9  1.8
# 127  2.8  5.6  2.1
# 128  3.0  5.8  1.6
# 129  2.8  6.1  1.9
# 130  3.8  6.4  2.0
# 131  2.8  5.6  2.2
# 132  2.8  5.1  1.5
# 133  2.6  5.6  1.4
# 134  3.0  6.1  2.3
# 135  3.4  5.6  2.4
# 136  3.1  5.5  1.8
# 137  3.0  4.8  1.8
# 138  3.1  5.4  2.1
# 139  3.1  5.6  2.4
# 140  3.1  5.1  2.3
# 141  2.7  5.1  1.9
# 142  3.2  5.9  2.3
# 143  3.3  5.7  2.5
# 144  3.0  5.2  2.3
# 145  2.5  5.0  1.9
# 146  3.0  5.2  2.0
# 147  3.4  5.4  2.3
# 148  3.0  5.1  1.8
#
# [149 rows x 3 columns]

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 119    Iris-virginica
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# 129    Iris-virginica
# 130    Iris-virginica
# 131    Iris-virginica
# 132    Iris-virginica
# 133    Iris-virginica
# 134    Iris-virginica
# 135    Iris-virginica
# 136    Iris-virginica
# 137    Iris-virginica
# 138    Iris-virginica
# 139    Iris-virginica
# 140    Iris-virginica
# 141    Iris-virginica
# 142    Iris-virginica
# 143    Iris-virginica
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# Name: Iris-setosa, Length: 149, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , Y_train , Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)
print("there are {} training samples and {} test samples".format(X_train.shape[0], X_test.shape[0]))
# Out:
# there are 104 training samples and 45 test samples

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

sc = StandardScaler()
sc.fit(X_train)
x_train_std = sc.transform(X_train)
x_test_std = sc.transform(X_test)

# %%
x_train_std.mean()
# Out:
# 3.416070845000482e-17

# %%
x_test_std.mean()
# Out:
# -0.17910990924241138

# %%
# support vector classification
from sklearn.svm import SVC

svm = SVC(kernel='rbf',random_state=0,gamma=0.10, C=10)
svm.fit(x_train_std,Y_train)

print("accuracy on training data {:.2f}".format(svm.score(x_train_std,Y_train)))

print("accuracy on test data {:.2f}".format(svm.score(x_test_std,Y_test)))
# Out:
# accuracy on training data 0.99
# accuracy on test data 0.89

# %%
# Apply K nearest neighbor classifier
from sklearn.neighbors import KNeighborsClassifier

knn= KNeighborsClassifier(n_neighbors=7 , p=2 , metric='minkowski')
knn.fit(x_train_std,Y_train)
print("accuracy on training data {:.2f}".format(knn.score(x_train_std,Y_train)))
print("accuracy on test data {:.2f}".format(knn.score(x_test_std,Y_test)))
# Out:
# accuracy on training data 0.98
# accuracy on test data 0.93

# %%
# XGBoost

# %%
from sklearn import tree

d = tree.DecisionTreeClassifier(criterion="gini")
d.fit(x_train_std,Y_train)

print("train accuracy {:.2f}".format(d.score(x_train_std,Y_train)))
print("test accuracy {:.2f}".format(d.score(x_test_std,Y_test)))

# %%
from sklearn.ensemble import RandomForestClassifier

d = RandomForestClassifier()
d.fit(x_train_std,Y_train)

print("train accuracy {:.2f}".format(d.score(x_train_std,Y_train)))
print("test accuracy {:.2f}".format(d.score(x_test_std,Y_test)))

# %% [markdown]
# **************************
# ****Understand the data
#     Hypothesis generation
#     import, load, csv , etc
#     data structure and content
#     feature extraction
#     exploratory analysis
#
# **** Forecasting using multiple modelling techniques
#      splitting data into training and validation
#      modelling techniques
#      Holt's Linear Trend Model on daily time series
#      Introduction to ARIMA model
#      Parameter tuning for ARIMA model
#      SARIMAX model on daily time series

# %% [markdown]
# ****hypothesis generation
#
# traffic will increase over time. Because population increases.
# traffic will be high between from may-july , sept-nov. because tourists
# on working days higher. reason office and school/college
# on peak hours. because of office/school/college timings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import Series
from datetime import datetime

# %%
train = pd.read_csv('ts_train.csv')

# %%
test = pd.read_csv('ts_test.csv')

# %%
train_orig = train.copy()
test_orig = test.copy()

# %%
# data structure and content
train.columns, test.columns
# Out:
# (Index(['ID', 'Datetime', 'Count'], dtype='object'),
#  Index(['ID', 'Datetime'], dtype='object'))

# %%
train.dtypes, test.dtypes
# Out:
# (ID           int64
#  Datetime    object
#  Count        int64
#  dtype: object, ID           int64
#  Datetime    object
#  dtype: object)

# %%
train.shape, test.shape
# Out:
# ((18288, 3), (5112, 2))

# %%
# feature extraction
train['Datetime'] = pd.to_datetime(train.Datetime, format="%d-%m-%Y %H:%M")
test['Datetime'] = pd.to_datetime(test.Datetime, format="%d-%m-%Y %H:%M")
train_orig['Datetime'] = pd.to_datetime(train.Datetime, format="%d-%m-%Y %H:%M")
test_orig['Datetime'] = pd.to_datetime(test.Datetime, format="%d-%m-%Y %H:%M")

# %%
for i in (train,test,train_orig,test_orig):
    i['year'] = i.Datetime.dt.year
    i['month'] = i.Datetime.dt.month
    i['day'] = i.Datetime.dt.day
    i['hour'] = i.Datetime.dt.hour

# %%
train['day of week'] = train['Datetime'].dt.dayofweek

# %%
temp = train['Datetime']
temp
# Out:
# 0       2012-08-25 00:00:00
# 1       2012-08-25 01:00:00
# 2       2012-08-25 02:00:00
# 3       2012-08-25 03:00:00
# 4       2012-08-25 04:00:00
# 5       2012-08-25 05:00:00
# 6       2012-08-25 06:00:00
# 7       2012-08-25 07:00:00
# 8       2012-08-25 08:00:00
# 9       2012-08-25 09:00:00
# 10      2012-08-25 10:00:00
# 11      2012-08-25 11:00:00
# 12      2012-08-25 12:00:00
# 13      2012-08-25 13:00:00
# 14      2012-08-25 14:00:00
# 15      2012-08-25 15:00:00
# 16      2012-08-25 16:00:00
# 17      2012-08-25 17:00:00
# 18      2012-08-25 18:00:00
# 19      2012-08-25 19:00:00
# 20      2012-08-25 20:00:00
# 21      2012-08-25 21:00:00
# 22      2012-08-25 22:00:00
# 23      2012-08-25 23:00:00
# 24      2012-08-26 00:00:00
# 25      2012-08-26 01:00:00
# 26      2012-08-26 02:00:00
# 27      2012-08-26 03:00:00
# 28      2012-08-26 04:00:00
# 29      2012-08-26 05:00:00
#                 ...
# 18258   2014-09-24 18:00:00
# 18259   2014-09-24 19:00:00
# 18260   2014-09-24 20:00:00
# 18261   2014-09-24 21:00:00
# 18262   2014-09-24 22:00:00
# 18263   2014-09-24 23:00:00
# 18264   2014-09-25 00:00:00
# 18265   2014-09-25 01:00:00
# 18266   2014-09-25 02:00:00
# 18267   2014-09-25 03:00:00
# 18268   2014-09-25 04:00:00
# 18269   2014-09-25 05:00:00
# 18270   2014-09-25 06:00:00
# 18271   2014-09-25 07:00:00
# 18272   2014-09-25 08:00:00
# 18273   2014-09-25 09:00:00
# 18274   2014-09-25 10:00:00
# 18275   2014-09-25 11:00:00
# 18276   2014-09-25 12:00:00
# 18277   2014-09-25 13:00:00
# 18278   2014-09-25 14:00:00
# 18279   2014-09-25 15:00:00
# 18280   2014-09-25 16:00:00
# 18281   2014-09-25 17:00:00
# 18282   2014-09-25 18:00:00
# 18283   2014-09-25 19:00:00
# 18284   2014-09-25 20:00:00
# 18285   2014-09-25 21:00:00
# 18286   2014-09-25 22:00:00
# 18287   2014-09-25 23:00:00
# Name: Datetime, Length: 18288, dtype: datetime64[ns]

# %%
def checkweekend(data):
    if data.dayofweek == 5 or data.dayofweek == 6:
        return 1
    else :
        return 0
t2 = train['Datetime'].apply(checkweekend)
train['weekend']= t2

# %%
train.dtypes
# Out:
# ID                      int64
# Datetime       datetime64[ns]
# Count                   int64
# year                    int64
# month                   int64
# day                     int64
# hour                    int64
# day of week             int64
# weekend                 int64
# dtype: object

# %%
train.index = train['Datetime']
df = train.drop("ID",1)
ts = df['Count']
plt.figure(figsize=(16,8))
plt.plot(ts, label="Passenger count")
plt.title('Time series')
plt.xlabel('Time(year-month)')
plt.ylabel('Passenger count')
plt.legend(loc='best')

# %%
# exploratory analysis
train.groupby('year')['Count'].mean().plot.bar()

# %%
train.groupby(['year','month'])['Count'].mean().plot.bar()

# %%
t = train.groupby(['year','month'])['Count'].mean()
t.plot(figsize=(15,5),title ='Pax/mon', fontsize=14)

# %%
train.groupby('day')['Count'].mean().plot.bar()

# %%
train.groupby('hour')['Count'].mean().plot.bar()

# %%
train.groupby('weekend')['Count'].mean().plot.bar()

# %%
train.groupby('day of week')['Count'].mean().plot.bar()

# %%
train.dtypes
# Out:
# ID                      int64
# Datetime       datetime64[ns]
# Count                   int64
# year                    int64
# month                   int64
# day                     int64
# hour                    int64
# day of week             int64
# weekend                 int64
# dtype: object

# %%
train.Timestamp = pd.to_datetime(train.Datetime, format ="%d-%m-%Y %H:%M")
train.index = train.Timestamp
hourly = train.resample('H').mean()
daily = train.resample('D').mean()
weekly = train.resample('W').mean()
monthly = train.resample('M').mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
fig, axs = plt.subplots(4,1)

hourly.Count.plot(figsize=(15,8), title='Hourly', fontsize=14, ax=axs[0])
daily.Count.plot(figsize=(15,8), title='Daily', fontsize=14, ax=axs[1])
weekly.Count.plot(figsize=(15,8), title='Weekly', fontsize=14, ax=axs[2])
monthly.Count.plot(figsize=(15,8), title='Monthly', fontsize=14, ax=axs[3])

# %%
train.Timestamp = pd.to_datetime(train.Datetime, format="%d-%m-%Y %H:%M")

# %%
train.index= train.Timestamp

# %%
train= train.resample("D").mean()

# %%
test['Timestamp'] = pd.to_datetime(test.Datetime, format="%d-%m-%Y %H:%M")

# %%
test.index= test.Timestamp

# %%
test= test.resample("D").mean()

# %% [markdown]
# **** build models for time series forecasting.
# **** dataset for validation --> should have the actual values of the dependent variable
# **** model should not be trained using validation dataset
#
#
# ****divide the train data set into two parts : training and validation.
# ****time based split, first three months as the validation and rest as training

# %%
train_ds = train.ix['2012-08-25':'2014-06-24']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
train_ds
# Out:
#                  ID       Count    year  month   day  hour  day of week  \
# Datetime
# 2012-08-25     11.5    3.166667  2012.0    8.0  25.0  11.5          5.0
# 2012-08-26     35.5    3.666667  2012.0    8.0  26.0  11.5          6.0
# 2012-08-27     59.5    2.583333  2012.0    8.0  27.0  11.5          0.0
# 2012-08-28     83.5    2.416667  2012.0    8.0  28.0  11.5          1.0
# 2012-08-29    107.5    2.500000  2012.0    8.0  29.0  11.5          2.0
# 2012-08-30    131.5    3.083333  2012.0    8.0  30.0  11.5          3.0
# 2012-08-31    155.5    3.250000  2012.0    8.0  31.0  11.5          4.0
# 2012-09-01    179.5    4.666667  2012.0    9.0   1.0  11.5          5.0
# 2012-09-02    203.5    4.916667  2012.0    9.0   2.0  11.5          6.0
# 2012-09-03    227.5    4.500000  2012.0    9.0   3.0  11.5          0.0
# 2012-09-04    251.5    2.750000  2012.0    9.0   4.0  11.5          1.0
# 2012-09-05    275.5    4.333333  2012.0    9.0   5.0  11.5          2.0
# 2012-09-06    299.5    4.166667  2012.0    9.0   6.0  11.5          3.0
# 2012-09-07    323.5    2.833333  2012.0    9.0   7.0  11.5          4.0
# 2012-09-08    347.5    4.166667  2012.0    9.0   8.0  11.5          5.0
# 2012-09-09    371.5    2.833333  2012.0    9.0   9.0  11.5          6.0
# 2012-09-10    395.5    2.666667  2012.0    9.0  10.0  11.5          0.0
# 2012-09-11    419.5    2.416667  2012.0    9.0  11.0  11.5          1.0
# 2012-09-12    443.5    3.500000  2012.0    9.0  12.0  11.5          2.0
# 2012-09-13    467.5    3.000000  2012.0    9.0  13.0  11.5          3.0
# 2012-09-14    491.5    3.500000  2012.0    9.0  14.0  11.5          4.0
# 2012-09-15    515.5    3.833333  2012.0    9.0  15.0  11.5          5.0
# 2012-09-16    539.5    2.916667  2012.0    9.0  16.0  11.5          6.0
# 2012-09-17    563.5    3.833333  2012.0    9.0  17.0  11.5          0.0
# 2012-09-18    587.5    7.833333  2012.0    9.0  18.0  11.5          1.0
# 2012-09-19    611.5    6.583333  2012.0    9.0  19.0  11.5          2.0
# 2012-09-20    635.5    3.500000  2012.0    9.0  20.0  11.5          3.0
# 2012-09-21    659.5    3.750000  2012.0    9.0  21.0  11.5          4.0
# 2012-09-22    683.5    3.250000  2012.0    9.0  22.0  11.5          5.0
# 2012-09-23    707.5    4.250000  2012.0    9.0  23.0  11.5          6.0
# ...             ...         ...     ...    ...   ...   ...          ...
# 2014-05-26  15347.5  339.416667  2014.0    5.0  26.0  11.5          0.0
# 2014-05-27  15371.5  333.583333  2014.0    5.0  27.0  11.5          1.0
# 2014-05-28  15395.5  433.750000  2014.0    5.0  28.0  11.5          2.0
# 2014-05-29  15419.5  341.750000  2014.0    5.0  29.0  11.5          3.0
# 2014-05-30  15443.5  280.000000  2014.0    5.0  30.0  11.5          4.0
# 2014-05-31  15467.5  191.333333  2014.0    5.0  31.0  11.5          5.0
# 2014-06-01  15491.5  222.000000  2014.0    6.0   1.0  11.5          6.0
# 2014-06-02  15515.5  349.166667  2014.0    6.0   2.0  11.5          0.0
# 2014-06-03  15539.5  381.750000  2014.0    6.0   3.0  11.5          1.0
# 2014-06-04  15563.5  371.916667  2014.0    6.0   4.0  11.5          2.0
# 2014-06-05  15587.5  495.250000  2014.0    6.0   5.0  11.5          3.0
# 2014-06-06  15611.5  405.416667  2014.0    6.0   6.0  11.5          4.0
# 2014-06-07  15635.5  244.000000  2014.0    6.0   7.0  11.5          5.0
# 2014-06-08  15659.5  233.500000  2014.0    6.0   8.0  11.5          6.0
# 2014-06-09  15683.5  371.750000  2014.0    6.0   9.0  11.5          0.0
# 2014-06-10  15707.5  366.333333  2014.0    6.0  10.0  11.5          1.0
# 2014-06-11  15731.5  373.416667  2014.0    6.0  11.0  11.5          2.0
# 2014-06-12  15755.5  314.166667  2014.0    6.0  12.0  11.5          3.0
# 2014-06-13  15779.5  289.583333  2014.0    6.0  13.0  11.5          4.0
# 2014-06-14  15803.5  174.583333  2014.0    6.0  14.0  11.5          5.0
# 2014-06-15  15827.5  184.666667  2014.0    6.0  15.0  11.5          6.0
# 2014-06-16  15851.5  357.083333  2014.0    6.0  16.0  11.5          0.0
# 2014-06-17  15875.5  336.916667  2014.0    6.0  17.0  11.5          1.0
# 2014-06-18  15899.5  345.833333  2014.0    6.0  18.0  11.5          2.0
# 2014-06-19  15923.5  283.416667  2014.0    6.0  19.0  11.5          3.0
# 2014-06-20  15947.5  379.916667  2014.0    6.0  20.0  11.5          4.0
# 2014-06-21  15971.5  220.083333  2014.0    6.0  21.0  11.5          5.0
# 2014-06-22  15995.5  230.833333  2014.0    6.0  22.0  11.5          6.0
# 2014-06-23  16019.5  419.416667  2014.0    6.0  23.0  11.5          0.0
# 2014-06-24  16043.5  372.166667  2014.0    6.0  24.0  11.5          1.0
#
#             weekend
# Datetime
# 2012-08-25      1.0
# 2012-08-26      1.0
# 2012-08-27      0.0
# 2012-08-28      0.0
# 2012-08-29      0.0
# 2012-08-30      0.0
# 2012-08-31      0.0
# 2012-09-01      1.0
# 2012-09-02      1.0
# 2012-09-03      0.0
# 2012-09-04      0.0
# 2012-09-05      0.0
# 2012-09-06      0.0
# 2012-09-07      0.0
# 2012-09-08      1.0
# 2012-09-09      1.0
# 2012-09-10      0.0
# 2012-09-11      0.0
# 2012-09-12      0.0
# 2012-09-13      0.0
# 2012-09-14      0.0
# 2012-09-15      1.0
# 2012-09-16      1.0
# 2012-09-17      0.0
# 2012-09-18      0.0
# 2012-09-19      0.0
# 2012-09-20      0.0
# 2012-09-21      0.0
# 2012-09-22      1.0
# 2012-09-23      1.0
# ...             ...
# 2014-05-26      0.0
# 2014-05-27      0.0
# 2014-05-28      0.0
# 2014-05-29      0.0
# 2014-05-30      0.0
# 2014-05-31      1.0
# 2014-06-01      1.0
# 2014-06-02      0.0
# 2014-06-03      0.0
# 2014-06-04      0.0
# 2014-06-05      0.0
# 2014-06-06      0.0
# 2014-06-07      1.0
# 2014-06-08      1.0
# 2014-06-09      0.0
# 2014-06-10      0.0
# 2014-06-11      0.0
# 2014-06-12      0.0
# 2014-06-13      0.0
# 2014-06-14      1.0
# 2014-06-15      1.0
# 2014-06-16      0.0
# 2014-06-17      0.0
# 2014-06-18      0.0
# 2014-06-19      0.0
# 2014-06-20      0.0
# 2014-06-21      1.0
# 2014-06-22      1.0
# 2014-06-23      0.0
# 2014-06-24      0.0
#
# [669 rows x 8 columns]

# %%
valid_ds  = train.ix['2014-06-25':'2014-09-25']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
valid_ds
# Out:
#                  ID       Count    year  month   day  hour  day of week  \
# Datetime
# 2014-06-25  16067.5  353.666667  2014.0    6.0  25.0  11.5          2.0
# 2014-06-26  16091.5  395.250000  2014.0    6.0  26.0  11.5          3.0
# 2014-06-27  16115.5  282.333333  2014.0    6.0  27.0  11.5          4.0
# 2014-06-28  16139.5  218.250000  2014.0    6.0  28.0  11.5          5.0
# 2014-06-29  16163.5  196.250000  2014.0    6.0  29.0  11.5          6.0
# 2014-06-30  16187.5  314.500000  2014.0    6.0  30.0  11.5          0.0
# 2014-07-01  16211.5  326.500000  2014.0    7.0   1.0  11.5          1.0
# 2014-07-02  16235.5  326.083333  2014.0    7.0   2.0  11.5          2.0
# 2014-07-03  16259.5  323.916667  2014.0    7.0   3.0  11.5          3.0
# 2014-07-04  16283.5  393.416667  2014.0    7.0   4.0  11.5          4.0
# 2014-07-05  16307.5  260.416667  2014.0    7.0   5.0  11.5          5.0
# 2014-07-06  16331.5  280.500000  2014.0    7.0   6.0  11.5          6.0
# 2014-07-07  16355.5  400.000000  2014.0    7.0   7.0  11.5          0.0
# 2014-07-08  16379.5  342.250000  2014.0    7.0   8.0  11.5          1.0
# 2014-07-09  16403.5  405.500000  2014.0    7.0   9.0  11.5          2.0
# 2014-07-10  16427.5  413.416667  2014.0    7.0  10.0  11.5          3.0
# 2014-07-11  16451.5  381.166667  2014.0    7.0  11.0  11.5          4.0
# 2014-07-12  16475.5  244.083333  2014.0    7.0  12.0  11.5          5.0
# 2014-07-13  16499.5  205.083333  2014.0    7.0  13.0  11.5          6.0
# 2014-07-14  16523.5  355.416667  2014.0    7.0  14.0  11.5          0.0
# 2014-07-15  16547.5  345.916667  2014.0    7.0  15.0  11.5          1.0
# 2014-07-16  16571.5  331.500000  2014.0    7.0  16.0  11.5          2.0
# 2014-07-17  16595.5  322.250000  2014.0    7.0  17.0  11.5          3.0
# 2014-07-18  16619.5  352.750000  2014.0    7.0  18.0  11.5          4.0
# 2014-07-19  16643.5  330.583333  2014.0    7.0  19.0  11.5          5.0
# 2014-07-20  16667.5  341.000000  2014.0    7.0  20.0  11.5          6.0
# 2014-07-21  16691.5  497.750000  2014.0    7.0  21.0  11.5          0.0
# 2014-07-22  16715.5  458.833333  2014.0    7.0  22.0  11.5          1.0
# 2014-07-23  16739.5  422.083333  2014.0    7.0  23.0  11.5          2.0
# 2014-07-24  16763.5  339.833333  2014.0    7.0  24.0  11.5          3.0
# ...             ...         ...     ...    ...   ...   ...          ...
# 2014-08-27  17579.5  520.666667  2014.0    8.0  27.0  11.5          2.0
# 2014-08-28  17603.5  379.250000  2014.0    8.0  28.0  11.5          3.0
# 2014-08-29  17627.5  413.750000  2014.0    8.0  29.0  11.5          4.0
# 2014-08-30  17651.5  352.583333  2014.0    8.0  30.0  11.5          5.0
# 2014-08-31  17675.5  290.166667  2014.0    8.0  31.0  11.5          6.0
# 2014-09-01  17699.5  436.000000  2014.0    9.0   1.0  11.5          0.0
# 2014-09-02  17723.5  573.500000  2014.0    9.0   2.0  11.5          1.0
# 2014-09-03  17747.5  509.000000  2014.0    9.0   3.0  11.5          2.0
# 2014-09-04  17771.5  446.000000  2014.0    9.0   4.0  11.5          3.0
# 2014-09-05  17795.5  532.500000  2014.0    9.0   5.0  11.5          4.0
# 2014-09-06  17819.5  339.833333  2014.0    9.0   6.0  11.5          5.0
# 2014-09-07  17843.5  286.500000  2014.0    9.0   7.0  11.5          6.0
# 2014-09-08  17867.5  426.000000  2014.0    9.0   8.0  11.5          0.0
# 2014-09-09  17891.5  546.000000  2014.0    9.0   9.0  11.5          1.0
# 2014-09-10  17915.5  483.000000  2014.0    9.0  10.0  11.5          2.0
# 2014-09-11  17939.5  424.166667  2014.0    9.0  11.0  11.5          3.0
# 2014-09-12  17963.5  375.416667  2014.0    9.0  12.0  11.5          4.0
# 2014-09-13  17987.5  253.333333  2014.0    9.0  13.0  11.5          5.0
# 2014-09-14  18011.5  238.166667  2014.0    9.0  14.0  11.5          6.0
# 2014-09-15  18035.5  445.333333  2014.0    9.0  15.0  11.5          0.0
# 2014-09-16  18059.5  670.000000  2014.0    9.0  16.0  11.5          1.0
# 2014-09-17  18083.5  569.833333  2014.0    9.0  17.0  11.5          2.0
# 2014-09-18  18107.5  458.333333  2014.0    9.0  18.0  11.5          3.0
# 2014-09-19  18131.5  543.083333  2014.0    9.0  19.0  11.5          4.0
# 2014-09-20  18155.5  341.083333  2014.0    9.0  20.0  11.5          5.0
# 2014-09-21  18179.5  379.250000  2014.0    9.0  21.0  11.5          6.0
# 2014-09-22  18203.5  588.166667  2014.0    9.0  22.0  11.5          0.0
# 2014-09-23  18227.5  554.333333  2014.0    9.0  23.0  11.5          1.0
# 2014-09-24  18251.5  702.333333  2014.0    9.0  24.0  11.5          2.0
# 2014-09-25  18275.5  589.666667  2014.0    9.0  25.0  11.5          3.0
#
#             weekend
# Datetime
# 2014-06-25      0.0
# 2014-06-26      0.0
# 2014-06-27      0.0
# 2014-06-28      1.0
# 2014-06-29      1.0
# 2014-06-30      0.0
# 2014-07-01      0.0
# 2014-07-02      0.0
# 2014-07-03      0.0
# 2014-07-04      0.0
# 2014-07-05      1.0
# 2014-07-06      1.0
# 2014-07-07      0.0
# 2014-07-08      0.0
# 2014-07-09      0.0
# 2014-07-10      0.0
# 2014-07-11      0.0
# 2014-07-12      1.0
# 2014-07-13      1.0
# 2014-07-14      0.0
# 2014-07-15      0.0
# 2014-07-16      0.0
# 2014-07-17      0.0
# 2014-07-18      0.0
# 2014-07-19      1.0
# 2014-07-20      1.0
# 2014-07-21      0.0
# 2014-07-22      0.0
# 2014-07-23      0.0
# 2014-07-24      0.0
# ...             ...
# 2014-08-27      0.0
# 2014-08-28      0.0
# 2014-08-29      0.0
# 2014-08-30      1.0
# 2014-08-31      1.0
# 2014-09-01      0.0
# 2014-09-02      0.0
# 2014-09-03      0.0
# 2014-09-04      0.0
# 2014-09-05      0.0
# 2014-09-06      1.0
# 2014-09-07      1.0
# 2014-09-08      0.0
# 2014-09-09      0.0
# 2014-09-10      0.0
# 2014-09-11      0.0
# 2014-09-12      0.0
# 2014-09-13      1.0
# 2014-09-14      1.0
# 2014-09-15      0.0
# 2014-09-16      0.0
# 2014-09-17      0.0
# 2014-09-18      0.0
# 2014-09-19      0.0
# 2014-09-20      1.0
# 2014-09-21      1.0
# 2014-09-22      0.0
# 2014-09-23      0.0
# 2014-09-24      0.0
# 2014-09-25      0.0
#
# [93 rows x 8 columns]

# %%
train_ds.Count.plot(figsize=(15,8), title='Daily Commuters', fontsize=14, label='')
train_ds.Count.plot(figsize=(15,8), title='Daily Commuters', fontsize=14, label='')

# %%
atrain = np.asarray(train_ds.Count)
apred = valid_ds.copy()
apred['naive'] = atrain[len(atrain)-1]

plt.figure(figsize=(12,8))
plt.plot(train_ds.index,train_ds['Count'], label='train')
plt.plot(valid_ds.index,valid_ds['Count'],label='valid')

# %%
# root mean square error
# measures distance between regression line and data points
from sklearn.metrics import mean_squared_error
from math import sqrt
rms = sqrt(mean_squared_error(valid_ds.Count,apred.naive))
print(rms)
# Out:
# 111.79050467496724

# %%
# moving average
bpred = valid_ds.copy()
bpred['mavg'] = train_ds['Count'].rolling(10).mean().iloc[-1]
plt.figure(figsize=(12,8))
plt.plot(train_ds.index,train_ds['Count'], label='train')
plt.plot(valid_ds.index,valid_ds['Count'],label='valid')
plt.plot(bpred.index,bpred['mavg'], label='forecast')
plt.legend(loc='best')
plt.title("Mavg forecast 10")
plt.show()

bpred = valid_ds.copy()
bpred['mavg'] = train_ds['Count'].rolling(20).mean().iloc[-1]
plt.figure(figsize=(12,8))
plt.plot(train_ds.index,train_ds['Count'], label='train')
plt.plot(valid_ds.index,valid_ds['Count'],label='valid')
plt.plot(bpred.index,bpred['mavg'], label='forecast')
plt.legend(loc='best')
plt.title("Mavg forecast 20")
plt.show()

bpred = valid_ds.copy()
bpred['mavg'] = train_ds['Count'].rolling(50).mean().iloc[-1]
plt.figure(figsize=(12,8))
plt.plot(train_ds.index,train_ds['Count'], label='train')
plt.plot(valid_ds.index,valid_ds['Count'],label='valid')
plt.plot(bpred.index,bpred['mavg'], label='forecast')
plt.legend(loc='best')
plt.title("Mavg forecast 50")
plt.show()

# %%
rms = sqrt(mean_squared_error(valid_ds.Count,bpred.mavg))
print(rms)
# Out:
# 144.19175679986802

# %%
# simple exponential smoothing
import statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
cpred = valid_ds.copy()
fit = SimpleExpSmoothing(np.asarray(train_ds['Count'])).fit(smoothing_level=0.6, )
cpred['ses']= fit.forecast(len(valid_ds))
# Out:
#   File "<ipython-input-68-4f8875ab0f69>", line 2
#     import statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
#                                     ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(12,8))
plt.plot(train_ds.index,train_ds['Count'], label='train')
plt.plot(valid_ds.index,valid_ds['Count'],label='valid')
plt.plot(bpred.index,bpred['mavg'], label='forecast')
plt.legend(loc='best')
plt.title("Mavg forecast 10")
plt.show()
