# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
train = pd.read_csv('optdigits-orig.tra.csv')

# %%
train
# Out:
#       BU handwritten digit database: E Alpaydin C Kaynak 1995
# 0                                          Training file
# 1                                          entwidth = 32
# 2                                         entheight = 32
# 3                                              depth = 1
# 4                                          density = 300
# 5                                           whitepix = 0
# 6                                            ntot = 1934
# 7                                          ndigit = 1934
# 8                                             nlower = 0
# 9                                             nupper = 0
# 10                                            nparag = 0
# 11                                        firstdigit = 0
# 12                                         lastdigit = 0
# 13                                        firstlower = 0
# 14                                         lastlower = 0
# ...

# %%
train = pd.read_csv('optdigits.tra.csv')

# %%
test = pd.read_csv('optdigits.tes.csv')

# %%
train
# Out:
#       0  1   6  15  12  1.1  0.1  0.2  0.3  7  ...   0.21  0.22  0.23  6.3  \
# 0     0  0  10  16   6    0    0    0    0  7  ...      0     0     0   10
# 1     0  0   8  15  16   13    0    0    0  1  ...      0     0     0    9
# 2     0  0   0   3  11   16    0    0    0  0  ...      0     0     0    0
# 3     0  0   5  14   4    0    0    0    0  0  ...      0     0     0    4
# 4     0  0  11  16  10    1    0    0    0  4  ...      3     0     0   10
# 5     0  0   1  11  13   11    7    0    0  0  ...      0     0     0    1
# 6     0  0   8  10   8    7    2    0    0  1  ...      0     0     0    4
# 7     0  0  15   2  14   13    2    0    0  0  ...      0     0     0   10
# 8     0  0   3  13  13    2    0    0    0  6  ...      0     0     0    3
# 9     0  0   6  14  14   16   16    8    0  0  ...      0     0     0   10
# 10    0  0   0   3  16   11    1    0    0  0  ...      0     0     0    0
# ...

# %%
test
# Out:
# Empty DataFrame
# Columns: [0,0,5,13,9,1,0,0,0,0,13,15,10,15,5,0,0,3,15,2,0,11,8,0,0,4,12,0,0,8,8,0,0,5,8,0,0,9,8,0,0,4,11,0,1,12,7,0,0,2,14,5,10,12,0,0,0,0,6,13,10,0,0,0,0
# 0,0,0,12,13,5,0,0,0,0,0,11,16,9,0,0,0,0,3,15,16,6,0,0,0,7,15,16,16,2,0,0,0,0,1,16,16,3,0,0,0,0,1,16,16,6,0,0,0,0,1,16,16,6,0,0,0,0,0,11,16,10,0,0,1
# 0,0,0,4,15,12,0,0,0,0,3,16,15,14,0,0,0,0,8,13,8,16,0,0,0,0,1,6,15,11,0,0,0,1,8,13,15,1,0,0,0,9,16,16,5,0,0,0,0,3,13,16,16,11,5,0,0,0,0,3,11,16,9,0,2
# 0,0,7,15,13,1,0,0,0,8,13,6,15,4,0,0,0,2,1,13,13,0,0,0,0,0,2,15,11,1,0,0,0,0,0,1,12,12,1,0,0,0,0,0,1,10,8,0,0,0,8,4,5,14,9,0,0,0,7,13,13,9,0,0,3
# 0,0,0,1,11,0,0,0,0,0,0,7,8,0,0,0,0,0,1,13,6,2,2,0,0,0,7,15,0,9,8,0,0,5,16,10,0,16,6,0,0,4,15,16,13,16,1,0,0,0,0,3,15,10,0,0,0,0,0,2,16,4,0,0,4
# 0,0,12,10,0,0,0,0,0,0,14,16,16,14,0,0,0,0,13,16,15,10,1,0,0,0,11,16,16,7,0,0,0,0,0,4,7,16,7,0,0,0,0,0,4,16,9,0,0,0,5,4,12,16,4,0,0,0,9,16,16,10,0,0,5
# ...

# %%
train.dtypes
# Out:
# 0       int64
# 1       int64
# 6       int64
# 15      int64
# 12      int64
# 1.1     int64
# 0.1     int64
# 0.2     int64
# 0.3     int64
# 7       int64
# 16      int64
# 6.1     int64
# 6.2     int64
# 10      int64
# 0.4     int64
# 0.5     int64
# 0.6     int64
# 8       int64
# 16.1    int64
# 2       int64
# 0.7     int64
# 11      int64
# 2.1     int64
# 0.8     int64
# 0.9     int64
# 5       int64
# 16.2    int64
# 3       int64
# 0.10    int64
# 5.1     int64
#         ...
# 3.1     int64
# 0.13    int64
# 8.1     int64
# 7.3     int64
# 0.14    int64
# 0.15    int64
# 4       int64
# 12.1    int64
# 0.16    int64
# 1.2     int64
# 13.1    int64
# 5.2     int64
# 0.17    int64
# 0.18    int64
# 0.19    int64
# 14      int64
# 9       int64
# 15.1    int64
# 9.1     int64
# 0.20    int64
# 0.21    int64
# 0.22    int64
# 0.23    int64
# 6.3     int64
# 14.1    int64
# 7.4     int64
# 1.3     int64
# 0.24    int64
# 0.25    int64
# 0.26    int64
# ...

# %%
test.dtypes
# Out:
# 0,0,5,13,9,1,0,0,0,0,13,15,10,15,5,0,0,3,15,2,0,11,8,0,0,4,12,0,0,8,8,0,0,5,8,0,0,9,8,0,0,4,11,0,1,12,7,0,0,2,14,5,10,12,0,0,0,0,6,13,10,0,0,0,0\n0,0,0,12,13,5,0,0,0,0,0,11,16,9,0,0,0,0,3,15,16,6,0,0,0,7,15,16,16,2,0,0,0,0,1,16,16,3,0,0,0,0,1,16,16,6,0,0,0,0,1,16,16,6,0,0,0,0,0,11,16,10,0,0,1\n0,0,0,4,15,12,0,0,0,0,3,16,15,14,0,0,0,0,8,13,8,16,0,0,0,0,1,6,15,11,0,0,0,1,8,13,15,1,0,0,0,9,16,16,5,0,0,0,0,3,13,16,16,11,5,0,0,0,0,3,11,16,9,0,2\n0,0,7,15,13,1,0,0,0,8,13,6,15,4,0,0,0,2,1,13,13,0,0,0,0,0,2,15,11,1,0,0,0,0,0,1,12,12,1,0,0,0,0,0,1,10,8,0,0,0,8,4,5,14,9,0,0,0,7,13,13,9,0,0,3\n0,0,0,1,11,0,0,0,0,0,0,7,8,0,0,0,0,0,1,13,6,2,2,0,0,0,7,15,0,9,8,0,0,5,16,10,0,16,6,0,0,4,15,16,13,16,1,0,0,0,0,3,15,10,0,0,0,0,0,2,16,4,0,0,4\n0,0,12,10,0,0,0,0,0,0,14,16,16,14,0,0,0,0,13,16,15,10,1,0,0,0,11,16,16,7,0,0,0,0,0,4,7,16,7,0,0,0,0,0,4,16,9,0,0,0,5,4,12,16,4,0,0,0,9,16,16,10,0,0,5\n0,0,0,12,13,0,0,0,0,0,5,16,8,0,0,0,0,0,13,16,3,0,0,0,0,0,14,13,0,0,0,0,0,0,15,12,7,2,0,0,0,0,13,16,13,16,3,0,0,0,
# ...

# %%
train.head(10)
# Out:
#    0  1   6  15  12  1.1  0.1  0.2  0.3  7  ...   0.21  0.22  0.23  6.3  14.1  \
# 0  0  0  10  16   6    0    0    0    0  7  ...      0     0     0   10    16
# 1  0  0   8  15  16   13    0    0    0  1  ...      0     0     0    9    14
# 2  0  0   0   3  11   16    0    0    0  0  ...      0     0     0    0     1
# 3  0  0   5  14   4    0    0    0    0  0  ...      0     0     0    4    12
# 4  0  0  11  16  10    1    0    0    0  4  ...      3     0     0   10    16
# 5  0  0   1  11  13   11    7    0    0  0  ...      0     0     0    1    13
# 6  0  0   8  10   8    7    2    0    0  1  ...      0     0     0    4    13
# 7  0  0  15   2  14   13    2    0    0  0  ...      0     0     0   10    12
# 8  0  0   3  13  13    2    0    0    0  6  ...      0     0     0    3    15
# 9  0  0   6  14  14   16   16    8    0  0  ...      0     0     0   10    12
#
#    7.4  1.3  0.24  0.25  0.26
# 0   15    3     0     0     0
# 1    0    0     0     0     7
# ...

# %%
test.head(10)
# Out:
# Empty DataFrame
# Columns: [0,0,5,13,9,1,0,0,0,0,13,15,10,15,5,0,0,3,15,2,0,11,8,0,0,4,12,0,0,8,8,0,0,5,8,0,0,9,8,0,0,4,11,0,1,12,7,0,0,2,14,5,10,12,0,0,0,0,6,13,10,0,0,0,0
# 0,0,0,12,13,5,0,0,0,0,0,11,16,9,0,0,0,0,3,15,16,6,0,0,0,7,15,16,16,2,0,0,0,0,1,16,16,3,0,0,0,0,1,16,16,6,0,0,0,0,1,16,16,6,0,0,0,0,0,11,16,10,0,0,1
# 0,0,0,4,15,12,0,0,0,0,3,16,15,14,0,0,0,0,8,13,8,16,0,0,0,0,1,6,15,11,0,0,0,1,8,13,15,1,0,0,0,9,16,16,5,0,0,0,0,3,13,16,16,11,5,0,0,0,0,3,11,16,9,0,2
# 0,0,7,15,13,1,0,0,0,8,13,6,15,4,0,0,0,2,1,13,13,0,0,0,0,0,2,15,11,1,0,0,0,0,0,1,12,12,1,0,0,0,0,0,1,10,8,0,0,0,8,4,5,14,9,0,0,0,7,13,13,9,0,0,3
# 0,0,0,1,11,0,0,0,0,0,0,7,8,0,0,0,0,0,1,13,6,2,2,0,0,0,7,15,0,9,8,0,0,5,16,10,0,16,6,0,0,4,15,16,13,16,1,0,0,0,0,3,15,10,0,0,0,0,0,2,16,4,0,0,4
# 0,0,12,10,0,0,0,0,0,0,14,16,16,14,0,0,0,0,13,16,15,10,1,0,0,0,11,16,16,7,0,0,0,0,0,4,7,16,7,0,0,0,0,0,4,16,9,0,0,0,5,4,12,16,4,0,0,0,9,16,16,10,0,0,5
# ...
