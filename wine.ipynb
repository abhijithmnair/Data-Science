# %% [markdown]
# ## Understanding Wine and Types

# %% [markdown]
#  Wine is an alcoholic beverage made from grapes which is fermented without the addition of sugars, acids, enzymes, water, or other nutrients
#
# Red wine is made from dark red and black grapes. The color usually ranges from various shades of red, brown and violet.
#
# This is produced with whole grapes including the skin which adds to the color and flavor of red wines, giving it a rich flavor.
#
# White wine is made from white grapes with no skins or seeds. The color is usually straw-yellow, yellow-green, or yellow-gold. Most white wines have a light and fruity flavor as compared to richer red wines

# %% [markdown]
# ## Understanding Wine Attributes and Properties

# %% [markdown]
# fixed acidity: Acids are one of the fundamental properties of wine and contribute greatly to the taste of the wine. Reducing acids significantly might lead to wines tasting flat. Fixed acids include tartaric, malic, citric, and succinic acids which are found in grapes (except succinic). This variable is usually expressed in  in the dataset.
#
# volatile acidity: These acids are to be distilled out from the wine before completing the production process. It is primarily constituted of acetic acid though other acids like lactic, formic and butyric acids might also be present. Excess of volatile acids are undesirable and lead to unpleasant flavor. In the US, the legal limits of volatile acidity are 1.2 g/L for red table wine and 1.1 g/L for white table wine. The volatile acidity is expressed in  in the dataset. It is for aroma.
#
# citric acid: This is one of the fixed acids which gives a wine its freshness. Usually most of it is consumed during the fermentation process and sometimes it is added separately to give the wine more freshness. It's usually expressed in  in the dataset.
#
# residual sugar: This typically refers to the natural sugar from grapes which remains after the fermentation process stops, or is stopped. It's usually expressed in  in the dataset.
#
# chlorides: This is usually a major contributor to saltiness in wine. It's usually expressed in  in the dataset.
#
# free sulfur dioxide: This is the part of the sulphur dioxide that when added to a wine is said to be free after the remaining part binds. Winemakers will always try to get the highest proportion of free sulphur to bind. They are also known as sulfites and too much of it is undesirable and gives a pungent odour. This variable is expressed in  in the dataset.
#
# total sulfur dioxide: This is the sum total of the bound and the free sulfur dioxide (). Here, it's expressed in . This is mainly added to kill harmful bacteria and preserve quality and freshness. There are usually legal limits for sulfur levels in wines and excess of it can even kill good yeast and give out undesirable odour.
#
# density: This can be represented as a comparison of the weight of a specific volume of wine to an equivalent volume of water. It is generally used as a measure of the conversion of sugar to alcohol. Here, it's expressed in .
#
# pH: Also known as the potential of hydrogen, this is a numeric scale to specify the acidity or basicity the wine. Fixed acidity contributes the most towards the pH of wines. You might know, solutions with a pH less than 7 are acidic, while solutions with a pH greater than 7 are basic. With a pH of 7, pure water is neutral. Most wines have a pH between 2.9 and 3.9 and are therefore acidic.
#
# sulphates: These are mineral salts containing sulfur. Sulphates are to wine as gluten is to food. They are a regular part of the winemaking around the world and are considered essential. They are connected to the fermentation process and affects the wine aroma and flavor. Here, it's expressed in  in the dataset.
#
# alcohol: Wine is an alcoholic beverage. Alcohol is formed as a result of yeast converting sugar during the fermentation process. The percentage of alcohol can vary from wine to wine. Hence it is not a surprise for this attribute to be a part of this dataset. It's usually measured in % vol or alcohol by volume (ABV).
#
# quality: Wine experts graded the wine quality between 0 (very bad) and 10 (very excellent). The eventual quality score is the median of at least three evaluations made by the same wine experts.

# %% [markdown]
# ## Dependent Attribute - Quality
# ## Independent Attributes - Fixed Acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulphur dioxide, total sulphur dioxide, density, pH, sulphates , alcohol

# %% [markdown]
# ## Hypothesis -
# 1) Quality Depends on Alcohol percentage
#
# 2) wine quality depends on fixed acidity value because of acidic nature.
#
# 3) acidity depends on ph higher the pH higher the acidity.

# %% [markdown]
# ## Step 1 - Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Step 2 - Import dataset and assign it to variable called train

# %%
train = pd.read_csv('Wine_Quality_Prediction.csv', sep=',')
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# ## Step 2.1 Check dtypes of each attribute from csv

# %%
train.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ## Step 2.2 View first 10 values from the data set

# %%
train.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
train.shape
# Out:
# (1599, 12)

# %%
fix = train['fixed acidity'].value_counts()
fix.head(5)
# Out:
# 7.2    67
# 7.1    57
# 7.8    53
# 7.5    52
# 7.0    50
# Name: fixed acidity, dtype: int64

# %%
vol = train['volatile acidity'].value_counts()
vol.head(5)
# Out:
# 0.60    47
# 0.50    46
# 0.43    43
# 0.59    39
# 0.36    38
# Name: volatile acidity, dtype: int64

# %%
cit = train['citric acid'].value_counts()
cit.head(5)
# Out:
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
# Name: citric acid, dtype: int64

# %%
res = train['residual sugar'].value_counts()
res.head(5)
# Out:
# 2.0    156
# 2.2    131
# 1.8    129
# 2.1    128
# 1.9    117
# Name: residual sugar, dtype: int64

# %%
chloride = train['chlorides'].value_counts()
chloride.head(5)
# Out:
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
# Name: chlorides, dtype: int64

# %%
free = train['free sulfur dioxide'].value_counts()
free.head(5)
# Out:
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# Name: free sulfur dioxide, dtype: int64

# %%
tot = train['total sulfur dioxide'].value_counts()
tot.head(5)
# Out:
# 28.0    43
# 24.0    36
# 18.0    35
# 15.0    35
# 23.0    34
# Name: total sulfur dioxide, dtype: int64

# %%
den = train['density'].value_counts()
den.head(5)
# Out:
# 0.9972    36
# 0.9976    35
# 0.9968    35
# 0.9980    29
# 0.9962    28
# Name: density, dtype: int64

# %%
ph = train['pH'].value_counts()
ph.head(5)
# Out:
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
# Name: pH, dtype: int64

# %%
sul = train['sulphates'].value_counts()
sul.head(5)
# Out:
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
# Name: sulphates, dtype: int64

# %%
alco = train['alcohol'].value_counts()
alco.head(5)
# Out:
# 9.5     139
# 9.4     103
# 9.8      78
# 9.2      72
# 10.5     67
# Name: alcohol, dtype: int64

# %%
train['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# ## Step 3 - Data Cleaning

# %%
pd.isna(train).sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
train.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
train.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
train.notnull().any()
# Out:
# fixed acidity           True
# volatile acidity        True
# citric acid             True
# residual sugar          True
# chlorides               True
# free sulfur dioxide     True
# total sulfur dioxide    True
# density                 True
# pH                      True
# sulphates               True
# alcohol                 True
# quality                 True
# dtype: bool

# %%
train.notnull().sum()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %% [markdown]
# ## Step 4 - Input Variables in Dataset

# %%
train.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
train.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ## Step - 4.1 Renaming columns

# %%
df = pd.DataFrame(train)
df
train = df.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity','citric acid':'citric_acid','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'})

# %%
train
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# ## Conclusion
# ## 1) There is huge difference between median and mean. Mean is very less than median.
# ## 2)  There is huge difference between 75% and max.
#
# ## Hence we conclude there are many outliers.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed_acidity           1599 non-null float64
# volatile_acidity        1599 non-null float64
# citric_acid             1599 non-null float64
# residual_sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free_sulfur_dioxide     1599 non-null float64
# total_sulfur_dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
train.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ## Step 5 - Data Exploration

# %%
import seaborn as sns

# %%
l = train.columns.values
number_of_columns=12
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(train[l[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# ## Step 5.1 Univariate Analysis

# %% [markdown]
# ## Why Univariate Analysis??
# ## We use univariate analysis to see the pattern of particular attribute only.

# %%
train.hist(bins=15, color='red', edgecolor='black', linewidth=1.0,
              xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 1.2, 1.2))   
rt = plt.suptitle('Univariate', x=0.65, y=1.25, fontsize=14)

# %%
sns.countplot(x='fixed_acidity', data=train)

# %%
sns.countplot(x='volatile_acidity', data=train)

# %%
# add new features: rating.
# quality 1-4 = bad, 5-6 = average, 8-10 = good
conditions = [
    (train['quality']>=7),
    (train['quality']<=4)
]
rating = ['good', 'bad']
train['rating']= np.select(conditions,rating,default='average')
train.rating.value_counts()
# Out:
# average    1319
# good        217
# bad          63
# Name: rating, dtype: int64

# %%
train.groupby('rating').mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# rating
# average       8.254284          0.538560     0.258264        2.503867
# bad           7.871429          0.724206     0.173651        2.684921
# good          8.847005          0.405530     0.376498        2.708756
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# rating
# average   0.088973            16.368461             48.946929  0.996867
# bad       0.095730            12.063492             34.444444  0.996689
# good      0.075912            13.981567             34.889401  0.996030
#
#                pH  sulphates    alcohol   quality
# rating
# average  3.311296   0.647263  10.252717  5.483700
# bad      3.384127   0.592222  10.215873  3.841270
# good     3.288802   0.743456  11.518049  7.082949

# %% [markdown]
# ## Correlation Matrix

# %% [markdown]
# ## Correlation basically means a mutual connection or relationship between two attributes

# %% [markdown]
# ## --> Here we are using heatmap for correlation. Heatmap is basically used for data visualization and also shows whether or not two variables are inversely or directly proportional

# %%
correlation = train.corr()
plt.figure(figsize=(14,8))
sns.heatmap(correlation, annot=True, linewidths=0, vmin=-1, cmap='RdBu_r')

# %%
#Quality correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'quality')['quality'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric_acid             0.226373
# fixed_acidity           0.124052
# residual_sugar          0.013732
# free_sulfur_dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total_sulfur_dioxide   -0.185100
# volatile_acidity       -0.390558
# Name: quality, dtype: float64

# %%
#pH correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'pH')['pH'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['pH'].sort_values(ascending=False)
# Out:
# pH                      1.000000
# volatile_acidity        0.234937
# alcohol                 0.205633
# free_sulfur_dioxide     0.070377
# quality                -0.057731
# total_sulfur_dioxide   -0.066495
# residual_sugar         -0.085652
# sulphates              -0.196648
# chlorides              -0.265026
# density                -0.341699
# citric_acid            -0.541904
# fixed_acidity          -0.682978
# Name: pH, dtype: float64

# %%
#Alcohol correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'alcohol')['alcohol'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['alcohol'].sort_values(ascending=False)
# Out:
# alcohol                 1.000000
# quality                 0.476166
# pH                      0.205633
# citric_acid             0.109903
# sulphates               0.093595
# residual_sugar          0.042075
# fixed_acidity          -0.061668
# free_sulfur_dioxide    -0.069408
# volatile_acidity       -0.202288
# total_sulfur_dioxide   -0.205654
# chlorides              -0.221141
# density                -0.496180
# Name: alcohol, dtype: float64

# %%
#fixed acidity correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'fixed_acidity')['fixed_acidity'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['fixed_acidity'].sort_values(ascending=False)
# Out:
# fixed_acidity           1.000000
# citric_acid             0.671703
# density                 0.668047
# sulphates               0.183006
# quality                 0.124052
# residual_sugar          0.114777
# chlorides               0.093705
# alcohol                -0.061668
# total_sulfur_dioxide   -0.113181
# free_sulfur_dioxide    -0.153794
# volatile_acidity       -0.256131
# pH                     -0.682978
# Name: fixed_acidity, dtype: float64

# %%
#volatile acidity correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'volatile_acidity')['volatile_acidity'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['volatile_acidity'].sort_values(ascending=False)
# Out:
# volatile_acidity        1.000000
# pH                      0.234937
# total_sulfur_dioxide    0.076470
# chlorides               0.061298
# density                 0.022026
# residual_sugar          0.001918
# free_sulfur_dioxide    -0.010504
# alcohol                -0.202288
# fixed_acidity          -0.256131
# sulphates              -0.260987
# quality                -0.390558
# citric_acid            -0.552496
# Name: volatile_acidity, dtype: float64

# %%
#citric acid correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'citric_acid')['citric_acid'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['citric_acid'].sort_values(ascending=False)
# Out:
# citric_acid             1.000000
# fixed_acidity           0.671703
# density                 0.364947
# sulphates               0.312770
# quality                 0.226373
# chlorides               0.203823
# residual_sugar          0.143577
# alcohol                 0.109903
# total_sulfur_dioxide    0.035533
# free_sulfur_dioxide    -0.060978
# pH                     -0.541904
# volatile_acidity       -0.552496
# Name: citric_acid, dtype: float64

# %%
#sulphates correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'sulphates')['sulphates'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['sulphates'].sort_values(ascending=False)
# Out:
# sulphates               1.000000
# chlorides               0.371260
# citric_acid             0.312770
# quality                 0.251397
# fixed_acidity           0.183006
# density                 0.148506
# alcohol                 0.093595
# free_sulfur_dioxide     0.051658
# total_sulfur_dioxide    0.042947
# residual_sugar          0.005527
# pH                     -0.196648
# volatile_acidity       -0.260987
# Name: sulphates, dtype: float64

# %%
#free sulfur dioxide correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'free_sulfur_dioxide')['free_sulfur_dioxide'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['free_sulfur_dioxide'].sort_values(ascending=False)
# Out:
# free_sulfur_dioxide     1.000000
# total_sulfur_dioxide    0.667666
# residual_sugar          0.187049
# pH                      0.070377
# sulphates               0.051658
# chlorides               0.005562
# volatile_acidity       -0.010504
# density                -0.021946
# quality                -0.050656
# citric_acid            -0.060978
# alcohol                -0.069408
# fixed_acidity          -0.153794
# Name: free_sulfur_dioxide, dtype: float64

# %%
#total sulfur dioxide correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'total_sulfur_dioxide')['total_sulfur_dioxide'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['total_sulfur_dioxide'].sort_values(ascending=False)
# Out:
# total_sulfur_dioxide    1.000000
# free_sulfur_dioxide     0.667666
# residual_sugar          0.203028
# volatile_acidity        0.076470
# density                 0.071269
# chlorides               0.047400
# sulphates               0.042947
# citric_acid             0.035533
# pH                     -0.066495
# fixed_acidity          -0.113181
# quality                -0.185100
# alcohol                -0.205654
# Name: total_sulfur_dioxide, dtype: float64

# %%
#chlorides correlation matrix
k = 12 #number of variables for heatmap
cols = train.corr().nlargest(k, 'chlorides')['chlorides'].index
cm = train[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
correlation['chlorides'].sort_values(ascending=False)
# Out:
# chlorides               1.000000
# sulphates               0.371260
# citric_acid             0.203823
# density                 0.200632
# fixed_acidity           0.093705
# volatile_acidity        0.061298
# residual_sugar          0.055610
# total_sulfur_dioxide    0.047400
# free_sulfur_dioxide     0.005562
# quality                -0.128907
# alcohol                -0.221141
# pH                     -0.265026
# Name: chlorides, dtype: float64

# %% [markdown]
# volatile acidity, citric acid , chlorides ,density and alcohol plays major role in classifying wine quality

# %% [markdown]
# ## Findings

# %% [markdown]
# 1) From above co relation graph we conclude that the attributes alcohol ,sulphates,citric_acid,fixed_acidity have positive correlation with quality attribute
#
# 2) total sulphur dioxide and volatile acidity have negative co relation

# %% [markdown]
# ## Step 5.2 Multivariate Analysis

# %% [markdown]
# ## Why Multi variate analysis??

# %% [markdown]
# ## When we need to check how one factor affects rest of them we do multivariate analysis

# %% [markdown]
# ## In Bi variate analysis two factors are taken in conideration of how one affects other

# %%
bx = sns.boxplot(x='rating',y='sulphates',data=train)
bx.set(xlabel='rating', ylabel='Sulphates',title='Sulphates and rating')
# Out:
# [Text(0, 0.5, 'Sulphates'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'Sulphates and rating')]

# %%
bx = sns.boxplot(x='rating',y='alcohol',data=train)
bx.set(xlabel='rating', ylabel='alcohol',title='rating and alcohol')
# Out:
# [Text(0, 0.5, 'alcohol'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'rating and alcohol')]

# %%
bx = sns.boxplot(x='rating',y='citric_acid',data=train)
bx.set(xlabel='rating', ylabel='citric_acid',title='rating and citric acid quality')
# Out:
# [Text(0, 0.5, 'citric_acid'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'rating and citric acid quality')]

# %%
bx = sns.boxplot(x='rating',y='fixed_acidity',data=train)
bx.set(xlabel='Wine Quality', ylabel='Sulphates',title='fixed acidity and rating')
# Out:
# [Text(0, 0.5, 'Sulphates'),
#  Text(0.5, 0, 'Wine Quality'),
#  Text(0.5, 1.0, 'fixed acidity and rating')]

# %%
bx = sns.boxplot(x='rating',y='residual_sugar',data=train)
bx.set(xlabel='rating', ylabel='residual_sugar',title='residual sugar and rating')
# Out:
# [Text(0, 0.5, 'residual_sugar'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'residual sugar and rating')]

# %%
bx = sns.boxplot(x='rating',y='free_sulfur_dioxide',data=train)
bx.set(xlabel='rating', ylabel='free_sulfur_dioxide',title='free sulfur dioxide and rating')
# Out:
# [Text(0, 0.5, 'free_sulfur_dioxide'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'free sulfur dioxide and rating')]

# %%
bx = sns.boxplot(x='rating',y='pH',data=train)
bx.set(xlabel='rating', ylabel='pH',title='pH and rating')
# Out:
# [Text(0, 0.5, 'pH'), Text(0.5, 0, 'rating'), Text(0.5, 1.0, 'pH and rating')]

# %%
bx = sns.boxplot(x='rating',y='chlorides',data=train)
bx.set(xlabel='rating', ylabel='chlorides',title='chlorides and rating')
# Out:
# [Text(0, 0.5, 'chlorides'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'chlorides and rating')]

# %%
bx = sns.boxplot(x='rating',y='density',data=train)
bx.set(xlabel='rating', ylabel='density',title='density and rating')
# Out:
# [Text(0, 0.5, 'density'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'density and rating')]

# %%
bx = sns.boxplot(x='rating',y='total_sulfur_dioxide',data=train)
bx.set(xlabel='rating', ylabel='total_sulfur_dioxide',title='total sulfur dioxide and rating')
# Out:
# [Text(0, 0.5, 'total_sulfur_dioxide'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'total sulfur dioxide and rating')]

# %%
bx = sns.boxplot(x='rating',y='volatile_acidity',data=train)
bx.set(xlabel='rating', ylabel='volatile_acidity',title='volatile acidity and rating')
# Out:
# [Text(0, 0.5, 'volatile_acidity'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'volatile acidity and rating')]

# %%
train.plot('quality','alcohol',kind='scatter')

# %%
train.plot('quality','sulphates',kind='scatter')

# %%
train.plot('quality','citric_acid',kind='scatter')

# %%
train.plot('quality','fixed_acidity',kind='scatter')

# %%
train.plot('quality','residual_sugar',kind='scatter')

# %%
train.plot('quality','free_sulfur_dioxide',kind='scatter')

# %%
train.plot('quality','pH',kind='scatter')

# %%
train.plot('quality','chlorides',kind='scatter')

# %%
train.plot('quality','density',kind='scatter')

# %%
train.plot('quality','total_sulfur_dioxide',kind='scatter')

# %%
train.plot('quality','volatile_acidity',kind='scatter')

# %%
bx = sns.violinplot(x='rating',y='citric_acid',data=train)
bx.set(xlabel='Rating', ylabel='Citric Acid',title='Citric Acid and rating')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0, 0.5, 'Citric Acid'),
#  Text(0.5, 0, 'Rating'),
#  Text(0.5, 1.0, 'Citric Acid and rating')]

# %%
bx = sns.swarmplot(x='rating',y='sulphates',data=train)
bx.set(xlabel='rating', ylabel='Sulphates',title='Sulphates and rating')
# Out:
# [Text(0, 0.5, 'Sulphates'),
#  Text(0.5, 0, 'rating'),
#  Text(0.5, 1.0, 'Sulphates and rating')]

# %%
sns.lmplot(x='alcohol',y='residual_sugar',col='rating',data=train)

# %% [markdown]
# ## Will take Alcohol Percentage and Wine Quality

# %%
bx = sns.boxplot(x='quality',y='alcohol',data=train)
bx.set(xlabel='Wine Quality', ylabel='Alcohol Percent',title='Alcohol and wine quality')
# Out:
# [Text(0, 0.5, 'Alcohol Percent'),
#  Text(0.5, 0, 'Wine Quality'),
#  Text(0.5, 1.0, 'Alcohol and wine quality')]

# %% [markdown]
# ## Findings 2
#
# ## 1) Wine quality has positive correlation with alcohol. So, If we want good quality wine we need to increase alcohol percentage
#
# ## 2) Density Vs Quality gives negative correlation
#
# ## 3) Correlation of quality with residual sugar is not clearly visualizing but we can predict from box plot and scatter plot that as residual sugar values goes down for good quality wines whereas bad quality wines shows increment in the sugar values
#
# ## --> Sugar ratio should be less to make good quality of wine
#
# ## 4) Average and good wines have higher citric acid amount compared with bad quality wines.
#
# ## -->  As citric acid adds aroma to the wine. Good aroma leads to pleasant mood.
#
# ## 5) Good quality wine are less saltier so we need to decrease chlorides in wine
#
# ## 6) Wine Quality decrease with increase in pH and volatile acidity
#
# ## --> When pH increases acidity decreases which leads to increase in volatile acidity and decrease in quality of wine.
#
# ## --> Excess of volatile acidity leads to undesirable taste of wine.
#
# ## 7) From above box plots, we conclude that Higher the pH higher the fixed acidity which leads to good quality of wine
#
# ## 8) There is positive correlation between sulphates and quality.
#
# ## --> Sulphates are associated with fermentation process of wine. More fermented the wine is better the wine.
#
# ## 9) Free sulfur dioxide with increment decrease the quality of wine
#
# ## -> Free sulfur dioxide also known as sulphites when added in excess leads to pungent odour which can ruin mood of wine consumer
#
# ## 10) pH has negative correlation with fixed acidity whereas fixed acidity has positive correlation with quality
#
# ## --> As acidity increases pH decreases which is good. Reducing fixed acidity will make wine taste flat.

# %% [markdown]
# ## Step 5.3 To check distribution - Skewness

# %% [markdown]
# ## Skewness is checked to see the asymetric nature of probability distribution

# %%
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(train[l[i]],kde=True)

# %% [markdown]
# ## Step 6 - Modelling

# %%
train.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ## Linear Model

# %%
x = train.iloc[:,0:11]
x.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
y = train.iloc[:,11:12]
y.head(10)
# Out:
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5
# 5        5
# 6        5
# 7        7
# 8        7
# 9        5

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin = LinearRegression()

# %%
x_train.head(10)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1488            5.6              0.54         0.04             1.7      0.049
# 16              8.5              0.28         0.56             1.8      0.092
# 811            12.9              0.50         0.55             2.8      0.072
# 1041            6.9              0.49         0.19             1.7      0.079
# 306             7.6              0.62         0.32             2.2      0.082
# 520             9.8              0.25         0.49             2.7      0.088
# 1148            7.8              0.39         0.42             2.0      0.086
# 838            10.1              0.31         0.35             1.6      0.075
# 25              6.3              0.39         0.16             1.4      0.080
# 549             9.0              0.53         0.49             1.9      0.171
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
y_train.head(10)
# Out:
#       quality
# 1488        5
# 16          7
# 811         6
# 1041        6
# 306         5
# 520         6
# 1148        6
# 838         7
# 25          5
# 549         6

# %%
len(x_train)
# Out:
# 1071

# %%
len(x_test)
# Out:
# 528

# %%
len(y_train)
# Out:
# 1071

# %%
len(y_test)
# Out:
# 528

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lin
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lin.score(x_test,y_test)
# Out:
# 0.3291442255027932

# %%
lin.coef_
# Out:
# array([[ 3.62538142e-02, -1.06788836e+00, -1.78912703e-01,
#          4.29586073e-02, -1.82078335e+00,  2.01538578e-03,
#         -3.22736404e-03, -3.09496946e+01, -3.99158016e-01,
#          9.15256720e-01,  2.76669304e-01]])

# %% [markdown]
# ## Decision Tree

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
clf.score(x_test,y_test)
# Out:
# 0.6287878787878788

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(x_train, y_train)
y_predict = model.predict(x_test)

accuracy_score(y_test.values, y_predict)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# 0.6931818181818182

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.svm import SVC # "Support vector classifier"
model = SVC(kernel='linear', C=1E10)
model.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
