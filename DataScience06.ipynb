# %% [markdown]
# Mean Squared Error
#
# Difference between predicted and actual value
# Square + square/n

# %%
import pandas as pd
import numpy as np

# %%
m= pd.read_csv("bigmart_train.csv")

# %%
m
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
m["Item_Outlet_Sales"].mean()
# Out:
# 2181.2889135750365

# %%
(m["Item_Outlet_Sales"] - m["Item_Outlet_Sales"].mean())**2
# Out:
# 0       2.414447e+06
# 1       3.020179e+06
# 2       7.059178e+03
# 3       2.099337e+06
# 4       1.407981e+06
# 5       2.639585e+06
# 6       3.377274e+06
# 7       3.391029e+06
# 8       1.220341e+06
# 9       6.397086e+06
# 10      4.425739e+05
# 11      3.438751e+01
# 12      3.504928e+05
# 13      1.301861e+03
# 14      4.156009e+04
# 15      4.019176e+05
# 16      3.129285e+05
# 17      2.140049e+06
# 18      1.497664e+04
# 19      3.216404e+05
# 20      2.540189e+06
# 21      3.544764e+06
# 22      3.528618e+05
# 23      3.868701e+06
# 24      3.597608e+06
# 25      1.801987e+06
# 26      1.245476e+06
# 27      3.505723e+06
# 28      4.011426e+06
# 29      4.224886e+06
#             ...
# 8493    6.481561e+06
# 8494    2.953063e+05
# 8495    4.550095e+06
# 8496    2.352773e+06
# 8497    4.327809e+03
# 8498    3.364463e+05
# 8499    6.317660e+05
# 8500    7.495106e+04
# 8501    4.532681e+05
# 8502    7.035517e+05
# 8503    1.468042e+06
# 8504    3.831117e+06
# ...

# %%
((m["Item_Outlet_Sales"] - m["Item_Outlet_Sales"].mean())**2).sum()
# Out:
# 24817265077.89461

# %%
(((m["Item_Outlet_Sales"] - m["Item_Outlet_Sales"].mean())**2).sum())/m["Item_Outlet_Sales"].count()
# Out:
# 2911799.2582300375

# %%
m
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
y = "theta"1 x1 + "theta"2 x2 + "theta"0

y = 10 * tier 1 + 5 * tier 2 + 1 * tier 3

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
m.plot("Item_MRP","Item_Outlet_Sales",kind ="scatter")

# %% [markdown]
# sum of residuals - positive and negative values will cancel each other
# sum of absolute value of residuals
# sum of square of residuals (for more accuracy)
#
# minimizing the error
#
# (1/2*m) * sum((ft(X)- Y)**2)
# Cost Function
# gradient descent

# %%
#MRP, year of est.
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from sklearn.model_selection import train_test_split

train = pd.read_csv('bigmart_train.csv')

from sklearn.linear_model import LinearRegression
l= LinearRegression()

X= train.loc[:,['Outlet_Establishment_Year','Item_MRP']]
X
x_train , x_cv , y_train , y_cv = train_test_split(X,train.Item_Outlet_Sales)
l.fit(x_train,y_train)
l.predict(x_cv)
# Out:
# array([1267.33350713, 1143.0781934 , 3719.96759534, ..., 2191.54675227,
#        4022.41615294, 1184.74542238])

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from sklearn.model_selection import train_test_split

train = pd.read_csv('bigmart_train.csv')

from sklearn.linear_model import LinearRegression
l= LinearRegression()

X= train.loc[:,['Outlet_Establishment_Year','Item_MRP']]
X
x_train , x_cv , y_train , y_cv = train_test_split(X,train.Item_Outlet_Sales)
l.fit(x_train,y_train)
pred = l.predict(x_cv)
mse = np.mean((pred-y_cv)**2)
mse
# Out:
# 1963741.59167505

# %%
c = DataFrame(x_train.columns)
c['Coefficient Estimate']= Series(l.coef_)

# %%
c
# Out:
#                            0  Coefficient Estimate
# 0  Outlet_Establishment_Year            -10.869106
# 1                   Item_MRP             15.741717

# %%
m
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from sklearn.model_selection import train_test_split

train = pd.read_csv('bigmart_train.csv')

from sklearn.linear_model import LinearRegression
l= LinearRegression()

X= train.loc[:,['Item_Visibility','Item_MRP']]
X
x_train , x_cv , y_train , y_cv = train_test_split(X,train.Item_Outlet_Sales)
l.fit(x_train,y_train)
pred = l.predict(x_cv)
mse = np.mean((pred-y_cv)**2)
mse
# Out:
# 1958593.710242382

# %%
c = DataFrame(x_train.columns)
c['Coefficient Estimate']= Series(l.coef_)
c
# Out:
#                  0  Coefficient Estimate
# 0  Item_Visibility          -4036.075565
# 1         Item_MRP             15.655349

# %%
# R Square
# 0 = No Connection
# 1 = complete connection
l.score(x_cv,y_cv)
# Out:
# 0.33080717556779626

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from sklearn.model_selection import train_test_split

train = pd.read_csv('bigmart_train.csv')
train.Item_Weight.fillna(train.Item_Weight.mean())

train['Item_Visibility'] = \
     train['Item_Visibility'].replace(0,np.mean(train['Item_Visibility']))
train['']
from sklearn.linear_model import LinearRegression
l= LinearRegression()

X= train.loc[:,['Item_Visibility','Item_MRP']]
X
x_train , x_cv , y_train , y_cv = train_test_split(X,train.Item_Outlet_Sales)
l.fit(x_train,y_train)
pred = l.predict(x_cv)
mse = np.mean((pred-y_cv)**2)
mse
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-8814b98a3e9c> in <module>
#      12 X
#      13 x_train , x_cv , y_train , y_cv = train_test_split(X,train.Item_Outlet_Sales)
# ---> 14 l.fit(x_train,y_train)
#      15 pred = l.predict(x_cv)
#      16 mse = np.mean((pred-y_cv)**2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(pred,(pred - y_cv), c='b')
plt.hlines(y=0, xmin=-1000, xmax= 5000)
plt.title('residual plot')
# Out:
# Text(0.5, 1.0, 'residual plot')
